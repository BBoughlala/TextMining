# %% [markdown]
# # Creating a Knowledge Graph from the output of the NER & RE models
# This time, using a SpaCy implementation.

# %% [markdown]
# ## For Component 1

# %% [markdown]
# ### Instructions on how to work with Neo4j alongside this code
#
# Before you start, download neo4j desktop from https://neo4j.com/download/
#
# Then, create a project called "Text_Mining" (or whatever name you want, since this name is not used within this code).
#
# Click "Add" -> "Local DMBS" and name it "Text_Mining_Neo4j" (even though this name is also not used within this code) while setting the password to "bilalbroski1" (IMPORTANT!)
#
# Then you have to click the blue "Start" button and wait for the server to start. After it is done loading, click the blue "Open" button. This will cause the Neo4j Browser to open.
#
# In Neo4j browser, run the command "MATCH (n) RETURN n" to show the complete KG, and run "MATCH (n) DETACH DELETE n" to completely empty the DMBS.
#
# If any of this does not work, follow the steps in the "Download Neo4j" section of https://youtu.be/8jNPelugC2s?si=QV898-ggdLIq9XPk&t=597

# %%
import re
import os, os.path

from neo4j import GraphDatabase
from unidecode import unidecode
from num2words import num2words
import pickle
# from copy import deepcopy
import json

# # imports for loading the NER model using flair
# from flair.data import Sentence
# from flair.models import SequenceTagger

# import for loading the NER model using SpaCy
import spacy

# %%
# # # load the NER model using FLAIR
# # custom_ner_model = SequenceTagger.load(r'flair_models\best-model.pt')

# # Load the NER model using SpaCy
# custom_ner_model = spacy.load("model-best")
# Out:
# c:\Users\guusj\anaconda3\envs\2amm30\lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_pipeline' (0.0.0) was trained with spaCy v3.6 and may not be 100% compatible with the current version (3.6.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
# modified verison of what Bilal wrote on 26-01-2024
def augmented_text(data):
    augmented_data = []
    for example in data:
        old_text = example['text']
        new_text = ''
        cur_index = 0
        for entity in example['entities']:
            start = entity[0]
            end = entity[1]
            label = entity[2]

            if cur_index < start:
                new_text += old_text[cur_index:start]
                new_text += f'[{label}]{old_text[start:end]}[{label}]'
                cur_index = end
            else:
                new_text += f'[{label}]{old_text[start:end]}[{label}]'
                cur_index = end
            
        augmented_data.append(new_text)
    
    return augmented_data

# %%
# Create empty list to which the text(s) can be added
texts = []

# only execute if manually_select_texts is set to True
manually_select_texts = False

if manually_select_texts:

    # Set parameters for loading texts

    # set to True in case you want to select a single specific text
    select_text = True

    # index of the specific text that you want to select
    text_i = 369  # index of text for Thomas Alun Lockyer = 192; Mark Maria Hubertus Flekken = 369

    # if select_text is set to False, there will be nr_texts selected
    nr_texts = 2 # max number of texts is 1031

    # import the texts that have to be converted into a KG (=Knowledge Graph)

    texts = []

    if select_text: # only select the text with index text_i
        with open(f'./data/footballer_{text_i}.txt', 'r') as f:
            contents = f.read()
            texts.append(contents)
        f.close()
        print(f"The text with index number {text_i} has successfully been imported")

    else: # select the first nr_texts texts
        for i in range(nr_texts):
            with open(f'./data/footballer_{i}.txt', 'r') as f:
                contents = f.read()
                texts.append(contents)
            f.close()

        print(f"{len(texts)} texts have been successfully imported")

    print(texts)

else:
    text_ids = []

    with open(r'predictions.json','r') as data_file:    
        data = json.load(data_file)
        # for v in data:#[0].values():
        #     if v['id'] not in text_ids:
        #         # aug_text = augmented_text(v['text'])
        #         texts.append(v['text'])
        #         text_ids.append(v['id'])
#  "[PLAYER]Michail Gregory Antonio[PLAYER] (born [DATE]28 March 1990[DATE]) is a professional footballer who plays as a [POSITION]forward[POSITION] for club [CLUB]West Ham United[CLUB]. Born in [COUNTRY]England[COUNTRY], he represents the [COUNTRY]Jamaica[COUNTRY] national team. [PLAYER]Antonio[PLAYER] began his career at non-League club Tooting &amp; Mitcham United before signing with Reading of the Championship in 2008. The club sent him on subsequent loan spells to Cheltenham Town, back to Tooting &amp; Mitcham, [CLUB]Southampton[CLUB] and [CLUB]Colchester United[CLUB], as he struggled to find a place in Reading's first team throughout his four-year stay at the Madejski. A final loan spell with [CLUB]Sheffield Wednesday[CLUB] resulted in a permanent move in 2012, where he went on to make 64 appearances and score 12 goals. [CLUB]Nottingham Forest[CLUB] signed him from Wednesday in 2014, where his 16 goals in 50 appearances attracted attention from [CLUB]West Ham United[CLUB] of the Premier League, who signed him in 2015, where he was deployed in a number of positions including [POSITION]right back[POSITION], [POSITION]right midfielder[POSITION] and as a [POSITION]winger[POSITION] before eventually establishing himself as the club's main [POSITION]striker[POSITION]. On [DATE]23 August 2021[DATE], he became [CLUB]West Ham United[CLUB]'s all-time top scorer in the Premier League. Club career. Early career. [PLAYER]Antonio[PLAYER]"]

# %% [markdown]
# ## Preprocessing

# %%
def escapeRegExp(text):
    """
    Replace all of the opening brackets with "\[" to escape the special characters in the regrex.
    This is required to prevent unterminated character sets.
    If the unterminated character sets error still occurs, try running the commented out lines as well.
    Source: https://stackoverflow.com/questions/54135606/python-re-error-unterminated-character-set-at-position
    """
    edited_text = text.replace("[", "\[")
    # edited_text = edited_text.replace("{", "\{")
    # edited_text = edited_text.replace("(", "\(")
    # edited_text = edited_text.replace(")", "\)")
    return edited_text

# %%
final_texts = map(escapeRegExp, texts) # where the "texts" variable contains the augmented texts

# %%
def fix_var_name(var_name: str):
    """
    Check string for violations of the Cypher variable name conventions,
    namely that it must always start with a letter.
    If the string starts with an integer, replace it with the word for this integer.
    For example, 2_october becomes two_october.
    Remove apostrophes
    The handleable_case parameter is set to True if the input is a handleable case. If not,
    handleable_case will be set to False, which will lead to the abortion of the current iteration
    in which fix_var_name() is being used.
    """
    handleable_case = True # The case is assumed to be handleable

    # if the case is unhandable, handleable_case will be set to False
    if len(var_name)==1: # for variable names with a length of 1 
        handleable_case = False
    if len(var_name) > 30: # for variable names that are extremely long
        handleable_case = False 

    if len(var_name) > 0 and var_name[0].isdigit(): # this condition might cause the original error to occur again!!
        i_final_int = 0 # starts at zero to prevent index out of range error from occuring at var_name[i_final_int].isdigit() in the while statement
        
        while ( var_name[i_final_int].isdigit() ) and ( i_final_int < len(var_name) -1 ):
            i_final_int += 1
        
        if i_final_int > 0:
            var_name = num2words( var_name[ : i_final_int] ) + var_name[i_final_int : ]
            var_name = var_name.replace(" ", "_").replace("-", "_").lower() 
            
    return var_name, handleable_case

# %% [markdown]
# ## Automate creation of Cypher CREATE query

# %%
def clean_str(entity_str: str):
    """
    Takes a string that represents an entity in the create_entity_query function
    and removes symbols that cause problems when creating a Neo4j query.

    Also look at the if statement ("if i_final_int > 0") within the fix_var_name() function.
    """
    entity_str = entity_str.replace("-", "_")

    entity_str = entity_str.replace(" ", "_").lower()
    
    entity_str = entity_str.replace("'", "")
    entity_str = entity_str.replace('"','')
    entity_str = entity_str.replace(".", "")
    entity_str = entity_str.replace(",", "")
    entity_str = entity_str.replace(";", "")
    entity_str = entity_str.replace("(", "")
    entity_str = entity_str.replace(")", "")
    entity_str = entity_str.replace("&", "")
    entity_str = entity_str.replace("\\", "")
    entity_str = entity_str.replace("[", "")
    entity_str = entity_str.replace("]", "")

    entity_str = entity_str.strip("_")

    return entity_str

# %%
def modify_str(entity_str: str):
    """
    Takes the extracted string in the create_entity_query function, and modifies it
    according to the naming conventions of neo4j.
    """
    variable_str = entity_str.replace(" ", "_").lower() 
    variable_str, handleable = fix_var_name(variable_str)
    entity_str = entity_str.lower().title()

    # entity_str = entity_str.replace('"','').replace("'","")

    # apply clean_str() function
    variable_str = clean_str(variable_str)
    entity_str = clean_str(entity_str)

    return variable_str, entity_str, handleable

# %%
def create_entity_query(augmented_texts: list, suppress_warnings: bool=True):
    """
    Creates a Cypher query that creates the entity part of a Neo4j Database 
    using the entities from the augmented_texts list.
    
    Inputs:
    - augmented_texts: list containing the annotated texts that have to be converted into a KG
    - suppress_warnings: If True, the warnings about texts that the function skips over will be suppressed.

    Assumptions: 
    - If entity tags are nested, this is never with a depth higher than 1. This means that the
        nested entities should always be of the shape "[TAG_1]entity1_pt1 [TAG_2]entity2[TAG2] entity1_pt1[TAG_1]"
    
    Output: 
    - Each query-line has the following format: (variable_name:ENTITY_TAG{name: 'name'})
    - In this format, each variable_name is completely decapitalized and all 
        whitespaces have been replaced by underscores.
    - the name that is within the curly brackets of each entity has each individual word capitalized, 
        but that is the only preprocessing performed on it.
    """
    # initialise a set to which all query-strings are added, and that can later be concatenated into a single string.
    # This helps preventing duplicates
    query_set = set()
    # Initialise a set that keeps track of the node labels. This prevents the following error from occuring:
    # """ {message: Variable `akanji` already declared (line 256, column 2 (offset: 10988)) """ 
    node_label_set = set()
    # initialise variable that prevents a closing tag from being investigated by skipping the next iteration of the current for loop if it equals True
    skip_iteration = False 
    # initialise variable that skips over an entire nested tag structure after it has been analyzed
    skip_nested_structure = 0 

    for text in augmented_texts:

        # Find all of the opening brackets in the text
        brackets_open = [m.start() for m in re.finditer("\\[", text)]
        # Find all of the closing brackets in the text
        brackets_close = [m.start() for m in re.finditer("]", text)]

        if (len(brackets_open) % 2 > 0) or (len(brackets_close) % 2 > 0):
            if not suppress_warnings:
                print(f"An uneven number of brackets has been found! Namely length of BO = {len(brackets_open)} or length of BC = {len(brackets_close)}")
            continue
            
        if len(brackets_open) != len(brackets_close):
            if not suppress_warnings:
                print(f"There is an unequal number of opening and closing brackets! There is {len(brackets_open)} opening brackets, and {len(brackets_close)} closing brackets.")
            continue

        # Loop over each tag to create query lines for the entities they annotate, while accounting for nested tags.
        for i in range( len(brackets_open) -1 ): # -1 is to prevent the function from finding a next pair of brackets when arriving at the final pair of brackets

            # skip this iteration if the previous non-nested (opening) tag has already been investigated
            if skip_iteration:
                skip_iteration = False
                continue
            
            # skip this iteration if the current tag is part of an already investigated nested structure
            if skip_nested_structure:
                skip_nested_structure -= 1
                continue

            io = brackets_open[i] # index of opening bracket of the entity tag that is currently being looped over
            ic = brackets_close[i] # index of closing bracket of the entity tag that is currently being looped over
            opening_tag = text[io+1:ic] # find the opening tag

            # initialise the variables that are required when working with a nested tag
            io_next = -1 # index of the opening bracket of the tag that is under investigation in the while statement
            ic_next = -1 # index of the closing bracket of the tag that is under investigation in the while statement
            ie_tags = [] # initialise a list where the indices of the brackets of the inner entities' tags can be stored
                         # ie_tags[0][0] = opening bracket index of ie opening tag; 
                         # ie_tags[1][1] = closing bracket index of ie closing tag
            closing_tag = None # initialise the closing tag that we are trying to find
            next_tag = None # initialise the variable that finds the closing tag 
            # initialise variable that keeps track if the tag that is currently under investigation is a nested one
            is_nested = -1 # current tag is nested if is_nested > 0
            j = i+1 # initialise index to use in the while statement 
            
            while ( next_tag != opening_tag ) and ( j < len(brackets_open) - 1 ) :
                closing_tag = next_tag # Set the closing tag to the tag that was investigated in the previous loop of the while statement
                io_next = brackets_open[j] 
                ic_next = brackets_close[j]
                next_tag = text[io_next+1:ic_next]

                # Remember the indices of the brackets of the inner entities' tags
                ie_tags.append( [io_next, ic_next] ) 

                is_nested += 1
                j += 1

            if is_nested > 2 :
                if not suppress_warnings:
                    print(f"A tag has been encountered that is nested on more than a single level! It is located in between indices {io_next} and {ic_next}.")
                continue

            if is_nested > 0: # if the current tag is a nested tag
                # Explanation of used terminology: the inner entity (ie) is the entity that is nested within the outer entity (oe)

                # find the indices of the inner entity (ie)
                begin_ie = ie_tags[0][1] + 1 # index of the first letter of the inner entity
                end_ie = ie_tags[1][0] - 1 # index of the last letter of the inner entity
                
                # extract the inner entity (ie)
                inner_entity = text[ begin_ie: end_ie ].strip()

                ie_variable, inner_entity, handleable_ie = modify_str(inner_entity)

                # if the unhandable case happens where an entity has length 1, continue
                # if not inner_entity:
                #     continue

                # find the indices of the outer entity (oe)
                begin_oe = io + (len(opening_tag) + 2) # index of the first letter of the outer entity
                end_oe = brackets_open[i+3] - 2 # index of the last letter of the outer entity
                ie_ot = brackets_open[i+1] - 1 # index of the ie opening tag (=ie_ot)
                ie_ct = brackets_close[i+2] + 1 # index of the ie closing tag (=ie_ct)
                # extract the outer entity (oe)
                outer_entity = text[ begin_oe : ie_ot ] + inner_entity + text[ ie_ct : end_oe + 1 ].strip() 
                
                oe_variable, outer_entity, handleable_oe = modify_str(outer_entity)

                # if the unhandable case happens where an entity has length 1, continue
                if (not handleable_ie) or (not handleable_oe):
                    continue
                
                # Define the variable names for the node labels
                oe_node_name = unidecode(oe_variable)
                oe_node_name = oe_node_name.replace("-","_")
                ie_node_name = unidecode(ie_variable)
                ie_node_name = ie_node_name.replace("-","_")
                
                # check if these variable names are already contained in the set of variable names
                if (oe_node_name in node_label_set) or (ie_node_name in node_label_set):
                    continue

                # Create a Cypher-queriable line that can be used to add this entity to the KG
                query_line_oe = f"({oe_node_name}:{opening_tag}{{name: '{unidecode(outer_entity)}'}})" 
                query_set.add(query_line_oe) # add the query line to the set of all query lines that are going to be added to the KG
                node_label_set.add(oe_node_name) # add the variable name for the node label to the set of all node labels to prevent duplicates
                query_line_ie = f"({ie_node_name}:{closing_tag}{{name: '{unidecode(inner_entity)}'}})" 
                query_set.add(query_line_ie) # add the query line to the set of all query lines that are going to be added to the KG
                node_label_set.add(ie_node_name) # add the variable name for the node label to the set of all node labels to prevent duplicates

                # Make sure the current for loop skips over the remaining 3 tags from the current nested structure
                skip_nested_structure = 3 

            else: # if the current tag is not a nested one

                # extracting the name of the entity 
                begin_entity = io + (len(opening_tag) + 2) # index of the first letter of the entity
                end_entity = brackets_close[i+1] - (len(opening_tag) + 2) # index of the last letter of the entity
                
                entity = text[ begin_entity : end_entity  ].strip()

                entity_variable, entity, handleable = modify_str(entity)

                # if the unhandable case happens where an entity has length 1, continue
                if not handleable:
                    continue

                # Define the variable name for the node label
                node_name = unidecode(entity_variable)
                node_name = node_name.replace("-","_")

                # check if this variable name is already contained in the set of variable names
                if node_name in node_label_set:
                    continue

                # Create a Cypher-queriable line that can be used to add this entity to the KG
                query_line = f"({node_name}:{opening_tag}{{name: '{unidecode(entity)}'}})" 
                query_set.add(query_line) # add the query line to the set of all query lines that are going to be added to the KG
                node_label_set.add(node_name) # add the variable name for the node label to the set of all node labels to prevent duplicates

                # skip the next iteration of the current for loop to prevent a closing tag from being investigated
                skip_iteration = True

    return query_set

# %%
# Running create_entity_query on the first 10 texts of the dataset
query_set_NER = create_entity_query(final_texts, suppress_warnings=True)

# %%
# Show results
print('length of the set = ', len(query_set_NER))
print(query_set_NER)
# Out:
# length of the set =  542
# {"(berke_ozer:PLAYER{name: 'berke_ozer'})", "(aaron_james_ramsey:PLAYER{name: 'aaron_james_ramsey'})", "(swansea_city:CLUB{name: 'swansea_city'})", "(sixteen_august_2009:DATE{name: '16_august_2009'})", "(daniel_powell:PLAYER{name: 'daniel_powell'})", "(in_august_2010_career:CLUB{name: 'in_august_2010_career'})", "(mansfield:CLUB{name: 'mansfield'})", "(antonio:PLAYER{name: 'antonio'})", "(twenty_five_august_2012:DATE{name: '25_august_2012'})", "(kv_oostende:CLUB{name: 'kv_oostende'})", "(wayne_robert_hennessey:PLAYER{name: 'wayne_robert_hennessey'})", "(ivan_perisic:PLAYER{name: 'ivan_perisic'})", "(twenty_five_march_2015:DATE{name: '25_march_2015'})", "(arsenal:CLUB{name: 'arsenal'})", "(hennesseys:PLAYER{name: 'hennesseys'})", "(thirty_october_2021:DATE{name: '30_october_2021'})", "(dynamo_moscow:CLUB{name: 'dynamo_moscow'})", "(mke_ankaragucu:CLUB{name: 'mke_ankaragucu'})", "(gateshead:CLUB{name: 'gateshead'})", "(de_bruyne:PLAYER{name: 'de_bruyne'})", "(twenty_one_november_1991:DATE{name: '21_november_1991'})", "(sessegnon_helped_fulham:PLAYER{name: 'sessegnon_helped_fulham'})", "(radu:PLAYER{name: 'radu'})", "(stephane_sessegnon:PLAYER{name: 'stephane_sessegnon'})", "(torino:CLUB{name: 'torino'})", "(wrexham:CLUB{name: 'wrexham'})", "(at_week_4_encounter_against:PLAYER{name: 'at_week_4_encounter_against'})", "(twenty_seven_may_2016:DATE{name: '27_may_2016'})", "(july_2010:DATE{name: 'july_2010'})", "(clynebegan_his_career_at:CLUB{name: 'clynebegan_his_career_at'})", "(fenerbahce:CLUB{name: 'fenerbahce'})", "(danish:NATIONALITY{name: 'danish'})", "(northern_ireland:COUNTRY{name: 'northern_ireland'})", "(american:NATIONALITY{name: 'american'})", "(dutch:NATIONALITY{name: 'dutch'})", "(fifteen_december_1989:DATE{name: '15_december_1989'})", "(ogbonna:PLAYER{name: 'ogbonna'})", "(fourteen_april_1998:DATE{name: '14_april_1998'})", "(viitorul:CLUB{name: 'viitorul'})", "(cardiff_city:CLUB{name: 'cardiff_city'})", "(west_bromwich_albion:CLUB{name: 'west_bromwich_albion'})", "(colchester_united:CLUB{name: 'colchester_united'})", "(fifteen_january_1994:DATE{name: '15_january_1994'})", "(twenty_seven_september_2013:DATE{name: '27_september_2013'})", "(fifteen_october_2022:DATE{name: '15_october_2022'})", "(portugal:COUNTRY{name: 'portugal'})", "(swindon_town:CLUB{name: 'swindon_town'})", "(eleven_october_1988:DATE{name: '11_october_1988'})", "(new_york_red_bulls:CLUB{name: 'new_york_red_bulls'})", "(pascal_gross:PLAYER{name: 'pascal_gross'})", "(tranmere:CLUB{name: 'tranmere'})", "(leicester_city:CLUB{name: 'leicester_city'})", "(southampton:CLUB{name: 'southampton'})", "(burnley:CLUB{name: 'burnley'})", "(andrei_radu:PLAYER{name: 'andrei_radu'})", "(october_5_1987:DATE{name: 'october_5_1987'})", "(in_a_4_0_win_against:CLUB{name: 'in_a_4-0_win_against'})", "(twenty_nine_january_2016:DATE{name: '29_january_2016'})", "(milners:PLAYER{name: 'milners'})", "(england:COUNTRY{name: 'england'})", "(werder_bremen:CLUB{name: 'werder_bremen'})", "(burnleys:CLUB{name: 'burnleys'})", "(ado:CLUB{name: 'ado'})", "(nottingham_forest:CLUB{name: 'nottingham_forest'})", "(alcorcon:CLUB{name: 'alcorcon'})", "(remi_walter:PLAYER{name: 'remi_walter'})", "(club_career:CLUB{name: 'club_career'})", "(thomas_david_heaton:PLAYER{name: 'thomas_david_heaton'})", "(romanian:NATIONALITY{name: 'romanian'})", "(scunthorpe_united:CLUB{name: 'scunthorpe_united'})", "(in_2014_he_moved_to:CLUB{name: 'in_2014_he_moved_to'})", "(august_2010:DATE{name: 'august_2010'})", "(in_july_2010_he_then_joined:CLUB{name: 'in_july_2010_he_then_joined'})", "(beerschot:CLUB{name: 'beerschot'})", "(doku:PLAYER{name: 'doku'})", "(brentford:CLUB{name: 'brentford'})", "(chicago_fire:CLUB{name: 'chicago_fire'})", "(dawson:PLAYER{name: 'dawson'})", "(forward:POSITION{name: 'forward'})", "(christopher_paul_basham:PLAYER{name: 'christopher_paul_basham'})", "(northampton_town:CLUB{name: 'northampton_town'})", "(mark_maria_hubertus_flekken:PLAYER{name: 'mark_maria_hubertus_flekken'})", "(against ...

# %% [markdown]
# ## Create the Knowledge Graph in Neo4j

# %% [markdown]
# ### Implement the RE part of the query

# %%
# # import the output from the RE model
# # RE_data_path = "C:/Users/guusj/Documents/AAA_Master_DSAI/Y2Q1/2AMM30_Text_Mining/DATA/test_RE_output_flekken"
# # RE_data_path = "./test_RE_output_flekken"
# RE_data_path = "C:/Users/guusj/Documents/AAA_Master_DSAI/Y2Q1/2AMM30_Text_Mining/RESIT/Data Ivan/test_output/file_1"
# with open(RE_data_path, "rb") as fp:
#     re_output = pickle.load(fp)

# # preprocess the variable names of the entities within data. 
# # The variable names of the relationships already exist in the correct form
# for i in range(len(re_output)):
    
#     old_relation = re_output[i]

#     # perform preprocessing
#     new_relation_0 = old_relation[0].strip().replace(" ", "_").lower()
#     new_relation_2 = old_relation[2].strip().replace(" ", "_").lower()

#     # Make sure the imported variable names comply with the naming restrcitions of Cypher
#     new_relation_0, handleable0 = fix_var_name(new_relation_0)
#     new_relation_2, handleable2 = fix_var_name(new_relation_2)

#     if (not handleable0) or (not handleable2):
#         continue

#     # Combine all new entries into a tuple and use it to replace the old tuple
#     new_relation = (new_relation_0, old_relation[1], new_relation_2)
#     re_output[i] = new_relation

# # convert the re_output list into a set
# re_output = set(re_output)
# # show results
# # re_output

# %% [markdown]
# ### Implement the RE part of the query -> looping over all 50 texts

# %%
# Database Credentials

uri = "bolt://localhost:7687" # Click the copy button in the "Bolt port" row from the table that appears when you click NBA_example in Neo4j Desktop
userName = "neo4j"
password = "bilalbroski1" # password for Text_Mining_Neo4j DBMS

# %%
# Connect to the neo4j database server
graphDB_Driver = GraphDatabase.driver(uri, auth=(userName, password))

# %%
# variable that should be set to "True" when the CREATE query has to be run
# The reason why this variable exists, is that if you run the code multiple times 
# with create_DB set to True, there will be a lot of duplicates within Neo4j
create_DB = True

# %%
def create_relation_query(relations_set: set):
    """
    Creates a Cypher query that creates the relation/RE part of a Neo4j Database 
    
    Assumptions: 
    - relations_set is of shape: set((SUBJECT, relationship, OBJECT), ... ), where SUBJECT and OBJECT are variables 
        referring to entities and are contained within a tuple.
    - THE SUBJECTS, RELATIONSHIPS, AND OBJECTS HAVE THE SAME SHAPE/FORMAT AS IN THE NER MODEL, so
        - all have been unidecoded
        - subjects and objects have been stripped of leading and trailing whitespaces, are 
            completely in lowercase, and all leftover whitespaces have been replaced by underscores
    """
    # initialise a set to which all query-strings are added, and that can later be concatenated into a single string.
    # This helps preventing duplicates
    query_set = set()

    for s in relations_set:
        
        subj = clean_str( s[0].replace("'", "") )
        relation = s[1]
        obj = clean_str( s[2].replace("'", "") )

        query_line = f"({ unidecode(subj) })-[:{ relation }]->({ unidecode(obj) })" 
        query_set.add(query_line) # add the query line to the set of all query lines that are going to be added to the KG

    return query_set

# %%
def combine_queries(query_set_NER: set, query_set_RE: set):
    """
    Concatenate all of the query lines containing the named entities together with the query lines
    containing the relationships, in order to form one final Cypher query that can be ran to 
    create the KG.
    """
    # Concatenate all of the query lines to form one final Cypher query that creates the KG
    cqlCreate = """CREATE"""

    # add the entities from the NER set
    for i, line1 in enumerate(query_set_NER):
        if not i: # the first query entry should not be seperated from the CREATE statement with a comma
            cqlCreate = cqlCreate + ' \n' + line1
        else:
            cqlCreate = cqlCreate + ',\n' + line1

    # add the relationships from the RE set
    for j, line2 in enumerate(query_set_RE):
        if j == (len(query_set_RE)-1): # The final entry of the query should end with a semicolon
            cqlCreate = cqlCreate + ',\n' + line2 + ';'
        else:
            cqlCreate = cqlCreate + ',\n' + line2

    return cqlCreate

# %%
cqlEmpty = """match (n) detach delete n"""

# %%
# initialise set to add all outputs of the RE model to
RE_output_set = set()

RE_list = []

# Loop over all 50 texts
for text_id in range(50):

    RE_sublist = []

    # import the output from the RE model
    RE_data_path = f"C:/Users/guusj/Documents/AAA_Master_DSAI/Y2Q1/2AMM30_Text_Mining/RESIT/Data Ivan/test_output_C1/file_{text_id}"
    with open(RE_data_path, "rb") as fp:
        re_output = pickle.load(fp)

        # preprocess the variable names of the entities within data. 
        # The variable names of the relationships already exist in the correct form
        for i in range(len(re_output)):

            old_relation = re_output[i]

            # perform preprocessing
            new_relation_0 = old_relation[0].strip().replace(" ", "_").lower()
            new_relation_2 = old_relation[2].strip().replace(" ", "_").lower()

            # Make sure the imported variable names comply with the naming restrcitions of Cypher
            new_relation_0, handleable0 = fix_var_name(new_relation_0)
            new_relation_0 = unidecode(new_relation_0)
            new_relation_2, handleable2 = fix_var_name(new_relation_2)
            new_relation_2 = unidecode(new_relation_2)

            if (handleable0 and handleable2):
                # Combine all new entries into a tuple and use it to replace the old tuple
                new_relation = (new_relation_0, old_relation[1], new_relation_2)                
                re_output[i] = new_relation

            # convert the re_output list into a set
            # re_output = set(re_output)
            
            # add re_output to RE_output_set
            RE_output_set.add(new_relation)
            RE_sublist.append(new_relation)

    # STOP THE LOOP FOR EACH TEXT, SUCH THAT YOU CAN SCREENSHOT THE ACCOMPANYING KNOWLEDGE GRAPH IN NEO4J
    
    print()
    print()
    query_set_RE = create_relation_query(RE_output_set)
    RE_list.append(RE_sublist)
    print(f'query_set_RE text nr {text_id}: ', query_set_RE)
    print()
    
    cqlCreate = combine_queries(query_set_NER, query_set_RE)
    print(f'cqlCreate text nr {text_id}' , cqlCreate)
    print()

    # # Execute the CQL query to create the KG
    # if create_DB:
    #     with graphDB_Driver.session() as graphDB_Session:
    #         # Create nodes
    #         graphDB_Session.run(cqlCreate)

    # input("Press Enter to continue...")
    # print('continue after text_id nr ', text_id)
    # # Execute the CQL query to empty the KG
    # if create_DB:
    #     with graphDB_Driver.session() as graphDB_Session:
    #         # Create nodes
    #         graphDB_Session.run(cqlEmpty)
# Out:
# query_set_RE text nr 0:  {'(harry_nicholas_arter)-[:played_for]->(welling_united)', '(harry_nicholas_arter)-[:played_for]->(carlisle_united)', '(harry_nicholas_arter)-[:plays_as]->(defensive_midfielder)', '(harry_nicholas_arter)-[:played_for]->(charlton_athletic)', '(harry_nicholas_arter)-[:born]->(twenty_eight_december_1989)', '(harry_nicholas_arter)-[:played_for]->(bournemouth)', '(harry_nicholas_arter)-[:played_for]->(nottingham_forest)'}
#
# cqlCreate text nr 0 CREATE
# (berke_ozer:PLAYER{name: 'berke_ozer'}),
# (aaron_james_ramsey:PLAYER{name: 'aaron_james_ramsey'}),
# (swansea_city:CLUB{name: 'swansea_city'}),
# (sixteen_august_2009:DATE{name: '16_august_2009'}),
# (daniel_powell:PLAYER{name: 'daniel_powell'}),
# (in_august_2010_career:CLUB{name: 'in_august_2010_career'}),
# (mansfield:CLUB{name: 'mansfield'}),
# (antonio:PLAYER{name: 'antonio'}),
# (twenty_five_august_2012:DATE{name: '25_august_2012'}),
# (kv_oostende:CLUB{name: 'kv_oostende'}),
# (wayne_robert_hennessey:PLAYER{name: 'wayne_robert_hennessey'}),
# (ivan_perisic:PLAYER{name: 'ivan_perisic'}),
# (twenty_five_march_2015:DATE{name: '25_march_2015'}),
# (arsenal:CLUB{name: 'arsenal'}),
# (hennesseys:PLAYER{name: 'hennesseys'}),
# (thirty_october_2021:DATE{name: '30_october_2021'}),
# (dynamo_moscow:CLUB{name: 'dynamo_moscow'}),
# (mke_ankaragucu:CLUB{name: 'mke_ankaragucu'}),
# (gateshead:CLUB{name: 'gateshead'}),
# (de_bruyne:PLAYER{name: 'de_bruyne'}),
# (twenty_one_november_1991:DATE{name: '21_november_1991'}),
# (sessegnon_helped_fulham:PLAYER{name: 'sessegnon_helped_fulham'}),
# (radu:PLAYER{name: 'radu'}),
# (stephane_sessegnon:PLAYER{name: 'stephane_sessegnon'}),
# (torino:CLUB{name: 'torino'}),
# (wrexham:CLUB{name: 'wrexham'}),
# (at_week_4_encounter_against:PLAYER{name: 'at_week_4_encounter_against'}),
# (twenty_seven_may_2016:DATE{name: '27_may_2016'}),
# (july_2010:DATE{name: 'july_2010'}),
# (clynebegan_his_career_at:CLUB{name: 'clynebegan_his_career_at'}),
# (fenerbahce:CLUB{name: 'fenerbahce'}),
# (danish:NATIONALITY{name: 'danish'}),
# (northern_ireland:COUNTRY{name: 'northern_ireland'}),
# (american:NATIONALITY{name: 'american'}),
# (dutch:NATIONALITY{name: 'dutch'}),
# (fifteen_december_1989:DATE{name: '15_december_1989'}),
# (ogbonna:PLAYER{name: 'ogbonna'}),
# (fourteen_april_1998:DATE{name: '14_april_1998'}),
# (viitorul:CLUB{name: 'viitorul'}),
# (cardiff_city:CLUB{name: 'cardiff_city'}),
# (west_bromwich_albion:CLUB{name: 'west_bromwich_albion'}),
# (colchester_united:CLUB{name: 'colchester_united'}),
# (fifteen_january_1994:DATE{name: '15_january_1994'}),
# (twenty_seven_september_2013:DATE{name: '27_september_2013'}),
# (fifteen_october_2022:DATE{name: '15_october_2022'}),
# (portugal:COUNTRY{name: 'portugal'}),
# (swindon_town:CLUB{name: 'swindon_town'}),
# (eleven_october_1988:DATE{name: '11_october_1988'}),
# (new_york_red_bulls:CLUB{name: 'new_york_red_bulls'}),
# (pascal_gross:PLAYER{name: 'pascal_gross'}),
# (tranmere:CLUB{name: 'tranmere'}),
# (leicester_city:CLUB{name: 'leicester_city'}),
# (southampton:CLUB{name: 'southampton'}),
# (burnley:CLUB{name: 'burnley'}),
# (andrei_radu:PLAYER{name: 'andrei_radu'}),
# (october_5_1987:DATE{name: 'october_5_1987'}),
# (in_a_4_0_win_against:CLUB{name: 'in_a_4-0_win_against'}),
# (twenty_nine_january_2016:DATE{name: '29_january_2016'}),
# (milners:PLAYER{name: 'milners'}),
# (england:COUNTRY{name: 'england'}),
# (werder_bremen:CLUB{name: 'werder_bremen'}),
# (burnleys:CLUB{name: 'burnleys'}),
# (ado:CLUB{name: 'ado'}),
# (nottingham_forest:CLUB{name: 'nottingham_forest'}),
# (alcorcon:CLUB{name: 'alcorcon'}),
# (remi_walter:PLAYER{name: 'remi_walter'}),
# (club_career:CLUB{name: 'club_career'}),
# (thomas_david_heaton:PLAYER{name: 'thomas_david_heaton'}),
# (romanian:NATIONALITY{name: 'romanian'}),
# (scunthorpe_united:CLUB{name: 'scunthorpe_united'}),
# (in_2014_he_moved_to:CLUB{name: 'in_2014_he_moved_to'}),
# (august_2010:DATE{name: 'august_2010'}),
# (in_july_2010_he_then_joined:CLUB{name: 'in_july_2010_he_then_joined'}),
# (beerschot:CLUB{name: 'beerschot'}),
# (doku:PLAYER{name: 'doku'}),
# (brentford:CLUB{name: 'brentford'}),
# (chicago_fire:CLUB{name: 'chicago_fire'}),
# (dawson:PLAYER{name: 'dawson'}),
# (forward:POSITION{name: 'forward'}),
# (christopher_paul_basham:PLAYER{name: 'christopher_paul_basham'}),
# (northampton_town:CLUB{name: 'northampton_town'}),
# (mark_maria_hubertus_flekken:PLAYER{name: 'mark_maria_hubertus_flekken'}),
# (against:CLUB{name: 'against'}),
# (lenglet:PLAYER{name: 'lenglet'}),
# (twenty_seven_may_2002:DATE{name: '27_may_2002'}),
# (scotland:COUNTRY{name: 'scotland'}),
# (newcastles:CLUB{name: 'newcastles'}),
# (sligo_rovers:CLUB{name: 'sligo_rovers'}),
# (kaminski:PLAYER{name: 'kaminski'}),
# (avellino:CLUB{name: 'avellino'}),
# (twelve_may_1987:DATE{name: '12_may_1987'}),
# (fifteen_november_2018:DATE{name: '15_november_2018'}),
# (thomas_alun_lockyer:PLAYER{name: 'thomas_alun_lockyer'}),
# (manuel_obafemi_akanji:PLAYER{name: 'manuel_obafemi_akanji'}),
# (kaminskis:PLAYER{name: 'kaminskis'}),
# (carsonjoined_the:CLUB{name: 'carsonjoined_the'}),
# (gosport_borough:CLUB{name: 'gosport_borough'}),
# (brother_steven:PLAYER{name: 'brother_steven'}),
# (nuova_cassino:CLUB{name: 'nuova_cassino'}),
# (sheffield_united:CLUB{name: 'sheffield_united'}),
# (christian_dannemann_eriksen:PLAYER{name: 'christian_dannemann_eriksen'}),
# (ellis_harrison:PLAYER{name: 'ellis_harrison'}),
# (switzerland:COUNTRY{name: 'switzerland'}),
# (olympique_lyonnais:CLUB{name: 'olympique_lyonnais'}),
# (bayern_munich:CLUB{name: 'bayern_munich'}),
# (english:NATIONALITY{name: 'english'}),
# (goalkeeper:POSITION{name: 'goalkeeper'}),
# (barcelona:CLUB{name: 'barcelona'}),
# (st_catherines:CLUB{name: 'st_catherines'}),
# (louise_dier:PLAYER{name: 'louise_dier'}),
# (drc:COUNTRY{name: 'drc'}),
# (real_madrid_castilla:CLUB{name: 'real_madrid_castilla'}),
# (ipswich_town:CLUB{name: 'ipswich_town'}),
# (yeovil_town:CLUB{name: 'yeovil_town'}),
# (august_2011:DATE{name: 'august_2011'}),
# (linda_arter:PLAYER{name: 'linda_arter'}),
# (cork:PLAYER{name: 'cork'}),
# (doucoureplays_for_the:COUNTRY{name: 'doucoureplays_for_the'}),
# (madrid:CLUB{name: 'madrid'}),
# (center_back:POSITION{name: 'center_back'}),
# (annie:PLAYER{name: 'annie'}),
# (primarily_a:POSITION{name: 'primarily_a'}),
# (twenty_six_december_1990:DATE{name: '26_december_1990'}),
# (basham_returned:PLAYER{name: 'basham_returned'}),
# (rodriguez:PLAYER{name: 'rodriguez'}),
# (seventeen_june_1995:DATE{name: '17_june_1995'}),
# (ten_may_1988:DATE{name: '10_may_1988'}),
# (two_february_1989:DATE{name: '2_february_1989'}),
# (crystal_palace:CLUB{name: 'crystal_palace'}),
# (august_8_1997:DATE{name: 'august_8_1997'}),
# (striker:POSITION{name: 'striker'}),
# (right_midfielder:POSITION{name: 'right_midfielder'}),
# (konyaspor:CLUB{name: 'konyaspor'}),
# (chamberscould_also_play_at:POSITION{name: 'chamberscould_also_play_at'}),
# (he_can_also_play_as_a:POSITION{name: 'he_can_also_play_as_a'}),
# (wimbledon:CLUB{name: 'wimbledon'}),
# (genoa:CLUB{name: 'genoa'}),
# (lockyer:PLAYER{name: 'lockyer'}),
# (midfielder:POSITION{name: 'midfielder'}),
# (belgian:NATIONALITY{name: 'belgian'}),
# (germinal_beerschot:CLUB{name: 'germinal_beerschot'}),
# (rkvv_wdz:CLUB{name: 'rkvv_wdz'}),
# (charleroi:CLUB{name: 'charleroi'}),
# (merseyside:CLUB{name: 'merseyside'}),
# (ibv:CLUB{name: 'ibv'}),
# (june_2021:DATE{name: 'june_2021'}),
# (celtics:CLUB{name: 'celtics'}),
# (swindon:CLUB{name: 'swindon'}),
# (dalry_rovers:CLUB{name: 'dalry_rovers'}),
# (left_winger:POSITION{name: 'left_winger'}),
# (st_dominic:CLUB{name: 'st_dominic'}),
# (zaroury:PLAYER{name: 'zaroury'}),
# (charlie_collins:PLAYER{name: 'charlie_collins'}),
# (middlesbrough_two:CLUB{name: 'middlesbrough_two'}),
# (in_2021:CLUB{name: 'in_2021'}),
# (sochaux:CLUB{name: 'sochaux'}),
# (oh_leuven:CLUB{name: 'oh_leuven'}),
# (one_january_1993:DATE{name: '1_january_1993'}),
# (brighton_amp:CLUB{name: 'brighton_amp'}),
# (anass_zaroury:PLAYER{name: 'anass_zaroury'}),
# (denizlispor_which_fenerbahce:PLAYER{name: 'denizlispor_which_fenerbahce'}),
# (sao_paulo:CLUB{name: 'sao_paulo'}),
# (one_fc_saarbrucken:CLUB{name: '1_fc_saarbrucken'}),
# (twenty_two_september_1984:DATE{name: '22_september_1984'}),
# (st_albans_city:CLUB{name: 'st_albans_city'}),
# (on:CLUB{name: 'on'}),
# (carson:PLAYER{name: 'carson'}),
# (carlisle_united:CLUB{name: 'carlisle_united'}),
# (daniel_william_john_ings:PLAYER{name: 'daniel_william_john_ings'}),
# (twenty_nine_january_2022:DATE{name: '29_january_2022'}),
# (limburg:CLUB{name: 'limburg'}),
# (parma:CLUB{name: 'parma'}),
# (twenty_three_july_1992:DATE{name: '23_july_1992'}),
# (italian:NATIONALITY{name: 'italian'}),
# (seamus_coleman:PLAYER{name: 'seamus_coleman'}),
# (portsmouth:CLUB{name: 'portsmouth'}),
# (nineteen_july_1995:DATE{name: '19_july_1995'}),
# (sessegnon:PLAYER{name: 'sessegnon'}),
# (he_plays_for_the:COUNTRY{name: 'he_plays_for_the'}),
# (chelsea:CLUB{name: 'chelsea'}),
# (rangers:CLUB{name: 'rangers'}),
# (ings:PLAYER{name: 'ings'}),
# (june_2013:DATE{name: 'june_2013'}),
# (barnsley:CLUB{name: 'barnsley'}),
# (wolfsburg:CLUB{name: 'wolfsburg'}),
# (robinson:PLAYER{name: 'robinson'}),
# (one_december_2019:DATE{name: '1_december_2019'}),
# (ben_gannon_doak:PLAYER{name: 'ben_gannon_doak'}),
# (royal_antwerp:CLUB{name: 'royal_antwerp'}),
# (athletic:CLUB{name: 'athletic'}),
# (he_began_his_career_with:CLUB{name: 'he_began_his_career_with'}),
# (fifteen_april_1986:DATE{name: '15_april_1986'}),
# (italy:COUNTRY{name: 'italy'}),
# (right_back:POSITION{name: 'right_back'}),
# (july_2012:DATE{name: 'july_2012'}),
# (two_november_2006:DATE{name: '2_november_2006'}),
# (coleman:PLAYER{name: 'coleman'}),
# (motherwell:CLUB{name: 'motherwell'}),
# (finland:COUNTRY{name: 'finland'}),
# (bury:CLUB{name: 'bury'}),
# (three_january_2010:DATE{name: '3_january_2010'}),
# (amine_harit:PLAYER{name: 'amine_harit'}),
# (cremonese:CLUB{name: 'cremonese'}),
# (hennessey:PLAYER{name: 'hennessey'}),
# (in_january_2022_career:CLUB{name: 'in_january_2022_career'}),
# (september_2022:DATE{name: 'september_2022'}),
# (newcastle:CLUB{name: 'newcastle'}),
# (cardiff:CLUB{name: 'cardiff'}),
# (oud_heverlee_leuven:CLUB{name: 'oud_heverlee_leuven'}),
# (evertons:CLUB{name: 'evertons'}),
# (heaton:PLAYER{name: 'heaton'}),
# (twenty_three_february_1992:DATE{name: '23_february_1992'}),
# (ritchie:PLAYER{name: 'ritchie'}),
# (six_december_2020:DATE{name: '6_december_2020'}),
# (timothy_michael_krul:PLAYER{name: 'timothy_michael_krul'}),
# (ionut_andrei_radu:PLAYER{name: 'ionut_andrei_radu'}),
# (right_winger:POSITION{name: 'right_winger'}),
# (bristol_rovers:CLUB{name: 'bristol_rovers'}),
# (tubantia_borgerhout:PLAYER{name: 'tubantia_borgerhout'}),
# (clermont:CLUB{name: 'clermont'}),
# (jay_enrique_rodriguez:PLAYER{name: 'jay_enrique_rodriguez'}),
# (brightons:CLUB{name: 'brightons'}),
# (croatian:NATIONALITY{name: 'croatian'}),
# (radoslaw_murawski:PLAYER{name: 'radoslaw_murawski'}),
# (spanish:NATIONALITY{name: 'spanish'}),
# (fluminense:CLUB{name: 'fluminense'}),
# (centre_back:POSITION{name: 'centre_back'}),
# (blackburn_rovers:CLUB{name: 'blackburn_rovers'}),
# (eighteen_may_2000:DATE{name: '18_may_2000'}),
# (ayr_united:CLUB{name: 'ayr_united'}),
# (kevin_de_bruyne:PLAYER{name: 'kevin_de_bruyne'}),
# (greece:COUNTRY{name: 'greece'}),
# (full_back:POSITION{name: 'full_back'}),
# (twelve_june_2021:DATE{name: '12_june_2021'}),
# (silva:PLAYER{name: 'silva'}),
# (five_april_1991:DATE{name: '5_april_1991'}),
# (paddy:CLUB{name: 'paddy'}),
# (twenty_eight_may_1997:DATE{name: '28_may_1997'}),
# (wigan:CLUB{name: 'wigan'}),
# (dorchester_town:CLUB{name: 'dorchester_town'}),
# (ten_september_1989:DATE{name: '10_september_1989'}),
# (twenty_three_may_1988:DATE{name: '23_may_1988'}),
# (three_april_1988:DATE{name: '3_april_1988'}),
# (ireland:COUNTRY{name: 'ireland'}),
# (beninese:NATIONALITY{name: 'beninese'}),
# (derby_county:CLUB{name: 'derby_county'}),
# (arter:PLAYER{name: 'arter'}),
# (sixteen_november_2022:DATE{name: '16_november_2022'}),
# (rovers:CLUB{name: 'rovers'}),
# (fc_lugano:CLUB{name: 'fc_lugano'}),
# (stuttgarter_kickers_ii:CLUB{name: 'stuttgarter_kickers_ii'}),
# (uk:COUNTRY{name: 'uk'}),
# (evans:PLAYER{name: 'evans'}),
# (anderlecht:CLUB{name: 'anderlecht'}),
# (real_madrid:CLUB{name: 'real_madrid'}),
# (lloris:PLAYER{name: 'lloris'}),
# (three_september_1985:DATE{name: '3_september_1985'}),
# (blackpool:CLUB{name: 'blackpool'}),
# (sheffield_wednesday:CLUB{name: 'sheffield_wednesday'}),
# (brazil:COUNTRY{name: 'brazil'}),
# (milner:PLAYER{name: 'milner'}),
# (wales:COUNTRY{name: 'wales'}),
# (fc_porto:CLUB{name: 'fc_porto'}),
# (charlton:CLUB{name: 'charlton'}),
# (saved_a_penalty_shot_by:PLAYER{name: 'saved_a_penalty_shot_by'}),
# (attacking_midfielder_or:POSITION{name: 'attacking_midfielder_or'}),
# (ederson:PLAYER{name: 'ederson'}),
# (spain:COUNTRY{name: 'spain'}),
# (signed_for_his_local_clu:PLAYER{name: 'signed_for_his_local_clu'}),
# (george_henry_ivor_baldock:PLAYER{name: 'george_henry_ivor_baldock'}),
# (malian:NATIONALITY{name: 'malian'}),
# (doucoure:PLAYER{name: 'doucoure'}),
# (antonee_robinson:PLAYER{name: 'antonee_robinson'}),
# (or:POSITION{name: 'or'}),
# (fleetwood_town:CLUB{name: 'fleetwood_town'}),
# (pablo_sarabia_garcia:PLAYER{name: 'pablo_sarabia_garcia'}),
# (seventeen_march_2014:DATE{name: '17_march_2014'}),
# (left_back:POSITION{name: 'left_back'}),
# (wolverhampton_wanderers:CLUB{name: 'wolverhampton_wanderers'}),
# (french:NATIONALITY{name: 'french'}),
# (bursaspor_of_turkey:COUNTRY{name: 'bursaspor_of_turkey'}),
# (nineteen_august_2019:DATE{name: '19_august_2019'}),
# (st_johnstone:CLUB{name: 'st_johnstone'}),
# (ogbonnasigned_for:CLUB{name: 'ogbonnasigned_for'}),
# (sporting_cp:CLUB{name: 'sporting_cp'}),
# (october_2020:DATE{name: 'october_2020'}),
# (fc_winterthur:CLUB{name: 'fc_winterthur'}),
# (harry_nicholas_arter:PLAYER{name: 'harry_nicholas_arter'}),
# (leeds_youth:CLUB{name: 'leeds_youth'}),
# (six_may_1990:DATE{name: '6_may_1990'}),
# (accrington_stanley:CLUB{name: 'accrington_stanley'}),
# (rennes:CLUB{name: 'rennes'}),
# (twenty_eight_march_1990:DATE{name: '28_march_1990'}),
# (united_states:COUNTRY{name: 'united_states'}),
# (granada_cf:CLUB{name: 'granada_cf'}),
# (harun_tekin:PLAYER{name: 'harun_tekin'}),
# (twenty_eight_september_1985:DATE{name: '28_september_1985'}),
# (akanji:PLAYER{name: 'akanji'}),
# (serdar:NATIONALITY{name: 'serdar'}),
# (james_philip_milner:PLAYER{name: 'james_philip_milner'}),
# (twenty_six_august_2020:DATE{name: '26_august_2020'}),
# (may_2013:DATE{name: 'may_2013'}),
# (moroccan:NATIONALITY{name: 'moroccan'}),
# (city:CLUB{name: 'city'}),
# (new_hartley:CLUB{name: 'new_hartley'}),
# (irish:NATIONALITY{name: 'irish'}),
# (seven_february_2008:DATE{name: '7_february_2008'}),
# (krul:PLAYER{name: 'krul'}),
# (wycombe_wanderers:CLUB{name: 'wycombe_wanderers'}),
# (brighton:CLUB{name: 'brighton'}),
# (he_represents_the:COUNTRY{name: 'he_represents_the'}),
# (randolph:PLAYER{name: 'randolph'}),
# (defender:POSITION{name: 'defender'}),
# (michael_melka:PLAYER{name: 'michael_melka'}),
# (seven_november_2000:DATE{name: '7_november_2000'}),
# (bournemouth:CLUB{name: 'bournemouth'}),
# (bolton:CLUB{name: 'bolton'}),
# (brazilian:NATIONALITY{name: 'brazilian'}),
# (hull_city:CLUB{name: 'hull_city'}),
# (nathaniel_edwin_clyne:PLAYER{name: 'nathaniel_edwin_clyne'}),
# (ado_den_haag:CLUB{name: 'ado_den_haag'}),
# (bayindir:PLAYER{name: 'bayindir'}),
# (four_march_2017:DATE{name: '4_march_2017'}),
# (and:CLUB{name: 'and'}),
# (villa:CLUB{name: 'villa'}),
# (sunderland:CLUB{name: 'sunderland'}),
# (manchester_city:CLUB{name: 'manchester_city'}),
# (rochdale_st:CLUB{name: 'rochdale_st'}),
# (in_2015_after:CLUB{name: 'in_2015_after'}),
# (hugo_hadrien_dominique_lloris:PLAYER{name: 'hugo_hadrien_dominique_lloris'}),
# (west_ham_united:CLUB{name: 'west_ham_united'}),
# (cresswell:PLAYER{name: 'cresswell'}),
# (everton:CLUB{name: 'everton'}),
# (eleven_february_2007:DATE{name: '11_february_2007'}),
# (thirty_august_2022:DATE{name: '30_august_2022'}),
# (against_both:COUNTRY{name: 'against_both'}),
# (twenty_two_september_2011:DATE{name: '22_september_2011'}),
# (ipswich:CLUB{name: 'ipswich'}),
# (ac_arles_avignon:CLUB{name: 'ac_arles_avignon'}),
# (dundee_united:CLUB{name: 'dundee_united'}),
# (turkish:NATIONALITY{name: 'turkish'}),
# (norwich_city:CLUB{name: 'norwich_city'}),
# (january_2023:DATE{name: 'january_2023'}),
# (january_2019:DATE{name: 'january_2019'}),
# (twenty_three_october_1992:DATE{name: '23_october_1992'}),
# (twenty_eight_june_1991:DATE{name: '28_june_1991'}),
# (july_2020:DATE{name: 'july_2020'}),
# (fifteen_june_1991:DATE{name: '15_june_1991'}),
# (twenty_july_1988:DATE{name: '20_july_1988'}),
# (twenty_five_november_2018:DATE{name: '25_november_2018'}),
# (defensive_midfielder:POSITION{name: 'defensive_midfielder'}),
# (leeds_united:CLUB{name: 'leeds_united'}),
# (milner_went:PLAYER{name: 'milner_went'}),
# (steve_harper:PLAYER{name: 'steve_harper'}),
# (july_2008:DATE{name: 'july_2008'}),
# (in_2016_he_played_for:CLUB{name: 'in_2016_he_played_for'}),
# (milton_keynes_dons:CLUB{name: 'milton_keynes_dons'}),
# (fc_basel:CLUB{name: 'fc_basel'}),
# (dier:PLAYER{name: 'dier'}),
# (jonathan_grant_evans:PLAYER{name: 'jonathan_grant_evans'}),
# (second_striker_or:POSITION{name: 'second_striker_or'}),
# (rsc_anderlecht:CLUB{name: 'rsc_anderlecht'}),
# (twenty_eight_december_1989:DATE{name: '28_december_1989'}),
# (central_midfielder:POSITION{name: 'central_midfielder'}),
# (three_may_2012:DATE{name: '3_may_2012'}),
# (twenty_six_december_2021:DATE{name: '26_december_2021'}),
# (vfl_wolfsburg:CLUB{name: 'vfl_wolfsburg'}),
# (lallana:PLAYER{name: 'lallana'}),
# (fc_ingolstadt:CLUB{name: 'fc_ingolstadt'}),
# (seventeen_march_1988:DATE{name: '17_march_1988'}),
# (beat:CLUB{name: 'beat'}),
# (kvc_olympic_deurne:CLUB{name: 'kvc_olympic_deurne'}),
# (formerly:PLAYER{name: 'formerly'}),
# (netherlands:COUNTRY{name: 'netherlands'}),
# (hajduk_split:CLUB{name: 'hajduk_split'}),
# (milan:CLUB{name: 'milan'}),
# (twenty_four_january_1987:DATE{name: '24_january_1987'}),
# (twenty_three_august_2021:DATE{name: '23_august_2021'}),
# (forster:PLAYER{name: 'forster'}),
# (darren_edward_andrew_randolph:PLAYER{name: 'darren_edward_andrew_randolph'}),
# (ingolstadt:CLUB{name: 'ingolstadt'}),
# (borussia_dortmund:CLUB{name: 'borussia_dortmund'}),
# (baldock:PLAYER{name: 'baldock'}),
# (pundits:PLAYER{name: 'pundits'}),
# (eight_july_2019:DATE{name: '8_july_2019'}),
# (july_2019:DATE{name: 'july_2019'}),
# (perisic:PLAYER{name: 'perisic'}),
# (liverpool:CLUB{name: 'liverpool'}),
# (royal_excel_mouscron:CLUB{name: 'royal_excel_mouscron'}),
# (eleven_may_1992:DATE{name: '11_may_1992'}),
# (northampton:CLUB{name: 'northampton'}),
# (watford:CLUB{name: 'watford'}),
# (nine_november_2022:DATE{name: '9_november_2022'}),
# (port_vale:CLUB{name: 'port_vale'}),
# (palace:CLUB{name: 'palace'}),
# (german:NATIONALITY{name: 'german'}),
# (albion:CLUB{name: 'albion'}),
# (one_thousand_eight_hundred_and_ninety_nine_hoffenheim:CLUB{name: '1899_hoffenheim'}),
# (left_midfielder:POSITION{name: 'left_midfielder'}),
# (four_january_1986:DATE{name: '4_january_1986'}),
# (gross:CLUB{name: 'gross'}),
# (alemannia_aachen:CLUB{name: 'alemannia_aachen'}),
# (january_2011:DATE{name: 'january_2011'}),
# (he_went_on_to_represent:CLUB{name: 'he_went_on_to_represent'}),
# (august_2019:DATE{name: 'august_2019'}),
# (stoke_city:CLUB{name: 'stoke_city'}),
# (may_2003:DATE{name: 'may_2003'}),
# (daniel_johnson_burn:PLAYER{name: 'daniel_johnson_burn'}),
# (central_defender:POSITION{name: 'central_defender'}),
# (three_december_1994:DATE{name: '3_december_1994'}),
# (three_january_1988:DATE{name: '3_january_1988'}),
# (paris_saint_germain:CLUB{name: 'paris_saint_germain'}),
# (twelve_march_2013:DATE{name: '12_march_2013'}),
# (dunk:PLAYER{name: 'dunk'}),
# (alan_shearer:PLAYER{name: 'alan_shearer'}),
# (fifteen_april_2015:DATE{name: '15_april_2015'}),
# (eighteen_october_2008:DATE{name: '18_october_2008'}),
# (january_2017:DATE{name: 'january_2017'}),
# (sint_truiden:PLAYER{name: 'sint_truiden'}),
# (he_played_for:CLUB{name: 'he_played_for'}),
# (aaron_william_cresswell:PLAYER{name: 'aaron_william_cresswell'}),
# (welsh:NATIONALITY{name: 'welsh'}),
# (made_ten_appearances_for_the:PLAYER{name: 'made_ten_appearances_for_the'}),
# (ogc_nice:CLUB{name: 'ogc_nice'}),
# (inter_milan:CLUB{name: 'inter_milan'}),
# (newcastle_united:CLUB{name: 'newcastle_united'}),
# (twenty_nine_july_1989:DATE{name: '29_july_1989'}),
# (eleven_november_2005:DATE{name: '11_november_2005'}),
# (zulte_waregem:CLUB{name: 'zulte_waregem'}),
# (selhurst:CLUB{name: 'selhurst'}),
# (one_february_2021:DATE{name: '1_february_2021'}),
# (fc_steaua_bucuresti:CLUB{name: 'fc_steaua_bucuresti'}),
# (he_broke_into:CLUB{name: 'he_broke_into'}),
# (sarabia:PLAYER{name: 'sarabia'}),
# (made_his_debut_for_the:PLAYER{name: 'made_his_debut_for_the'}),
# (twenty_six_december_1986:DATE{name: '26_december_1986'}),
# (karlsruher_sc:CLUB{name: 'karlsruher_sc'}),
# (heywood_st_james:CLUB{name: 'heywood_st_james'}),
# (attacking_midfielder:POSITION{name: 'attacking_midfielder'}),
# (hereford_united:CLUB{name: 'hereford_united'}),
# (france:COUNTRY{name: 'france'}),
# (rochdale:CLUB{name: 'rochdale'}),
# (eriksen:PLAYER{name: 'eriksen'}),
# (st_louis_scott_gallagher:CLUB{name: 'st_louis_scott_gallagher'}),
# (greuther_furth:CLUB{name: 'greuther_furth'}),
# (celtic:CLUB{name: 'celtic'}),
# (and_a:POSITION{name: 'and_a'}),
# (stafford_rangers:CLUB{name: 'stafford_rangers'}),
# (porto:CLUB{name: 'porto'}),
# (belgium:COUNTRY{name: 'belgium'}),
# (adalberto_penaranda:PLAYER{name: 'adalberto_penaranda'}),
# (before_transferring_to:CLUB{name: 'before_transferring_to'}),
# (nine_may_1992:DATE{name: '9_may_1992'}),
# (queens_park_rangers:CLUB{name: 'queens_park_rangers'}),
# (casemiro:PLAYER{name: 'casemiro'}),
# (march_2022:DATE{name: 'march_2022'}),
# (twenty_six_january_2013:DATE{name: '26_january_2013'}),
# (moved_to_the_2_bundesliga_clu:PLAYER{name: 'moved_to_the_2_bundesliga_clu'}),
# (jack_frank_porteous_cork:PLAYER{name: 'jack_frank_porteous_cork'}),
# (twenty_five_june_1989:DATE{name: '25_june_1989'}),
# (chambers:PLAYER{name: 'chambers'}),
# (one_february_2016:DATE{name: '1_february_2016'}),
# (daniel:PLAYER{name: 'daniel'}),
# (wigan_athletic:CLUB{name: 'wigan_athletic'}),
# (croatia:COUNTRY{name: 'croatia'}),
# (welling_united:CLUB{name: 'welling_united'}),
# (blyth_town:CLUB{name: 'blyth_town'}),
# (tottenham_hotspur:CLUB{name: 'tottenham_hotspur'}),
# (shay_given:PLAYER{name: 'shay_given'}),
# (afc_bournemouth:CLUB{name: 'afc_bournemouth'}),
# (swiss:NATIONALITY{name: 'swiss'}),
# (five_october_2020:DATE{name: '5_october_2020'}),
# (ream:PLAYER{name: 'ream'}),
# (flekken:PLAYER{name: 'flekken'}),
# (ac_milan:CLUB{name: 'ac_milan'}),
# (two_may_2009:DATE{name: '2_may_2009'}),
# (bolton_wanderers:CLUB{name: 'bolton_wanderers'}),
# (a:POSITION{name: 'a'}),
# (ordering:CLUB{name: 'ordering'}),
# (tottenham:CLUB{name: 'tottenham'}),
# (clyne:PLAYER{name: 'clyne'}),
# (jeremy_baffour_doku:PLAYER{name: 'jeremy_baffour_doku'}),
# (from_his_loan_spell_at_aston:CLUB{name: 'from_his_loan_spell_at_aston'}),
# (thirteen_june_1993:DATE{name: '13_june_1993'}),
# (august_2018:DATE{name: 'august_2018'}),
# (on_loan_from:CLUB{name: 'on_loan_from'}),
# (luton_town:CLUB{name: 'luton_town'}),
# (palermo:CLUB{name: 'palermo'}),
# (scott_paul_carson:PLAYER{name: 'scott_paul_carson'}),
# (nine_march_1993:DATE{name: '9_march_1993'}),
# (lommel:CLUB{name: 'lommel'}),
# (basham:PLAYER{name: 'basham'}),
# (denmark:COUNTRY{name: 'denmark'}),
# (blyth_spartans:CLUB{name: 'blyth_spartans'}),
# (winger:POSITION{name: 'winger'}),
# (bristol_city:CLUB{name: 'bristol_city'}),
# (doak:PLAYER{name: 'doak'}),
# (in_march_2022_with:CLUB{name: 'in_march_2022_with'}),
# (in_2010_but_due_to:CLUB{name: 'in_2010_but_due_to'}),
# (thirty_october_2011:DATE{name: '30_october_2011'}),
# (radyr_rangers:CLUB{name: 'radyr_rangers'}),
# (ionut_radu:PLAYER{name: 'ionut_radu'}),
# (kouassi_ryan_sessegnon:PLAYER{name: 'kouassi_ryan_sessegnon'}),
# (matthew_thomas_ritchie:PLAYER{name: 'matthew_thomas_ritchie'}),
# (oliver_norburn:PLAYER{name: 'oliver_norburn'}),
# (in_2021_and_subsequently_to:CLUB{name: 'in_2021_and_subsequently_to'}),
# (gwynedd:COUNTRY{name: 'gwynedd'}),
# (rs_futebol:CLUB{name: 'rs_futebol'}),
# (he_returned_to:CLUB{name: 'he_returned_to'}),
# (auxerre:CLUB{name: 'auxerre'}),
# (charlton_athletic:CLUB{name: 'charlton_athletic'}),
# (birmingham_city:CLUB{name: 'birmingham_city'}),
# (sevilla:CLUB{name: 'sevilla'}),
# (manchester_united:CLUB{name: 'manchester_united'}),
# (germany:COUNTRY{name: 'germany'}),
# (in_2019_after_two_years_with:CLUB{name: 'in_2019_after_two_years_with'}),
# (:CLUB{name: ''}),
# (michail_gregory_antonio:PLAYER{name: 'michail_gregory_antonio'}),
# (july_2013:DATE{name: 'july_2013'}),
# (nancy:CLUB{name: 'nancy'}),
# (twelve_february_2008:DATE{name: '12_february_2008'}),
# (republic_of_ireland:COUNTRY{name: 'republic_of_ireland'}),
# (fourteen_february_1992:DATE{name: '14_february_1992'}),
# (radcliffe_borough:CLUB{name: 'radcliffe_borough'}),
# (kiko:PLAYER{name: 'kiko'}),
# (genk:CLUB{name: 'genk'}),
# (juventus:CLUB{name: 'juventus'}),
# (darlington:CLUB{name: 'darlington'}),
# (scottish:NATIONALITY{name: 'scottish'}),
# (abdoulaye_doucoure:PLAYER{name: 'abdoulaye_doucoure'}),
# (wandgas_fc:CLUB{name: 'wandgas_fc'}),
# (in_summer_2015:PLAYER{name: 'in_summer_2015'}),
# (aston_villa:CLUB{name: 'aston_villa'}),
# (fulham:CLUB{name: 'fulham'}),
# (box_to_box:POSITION{name: 'box_to_box'}),
# (on_26_december_in_a_3_1_win_at:CLUB{name: 'on_26_december_in_a_3-1_win_at'}),
# (lost_3_4_to:CLUB{name: 'lost_3-4_to'}),
# (on_loan_from_serie_a_side:CLUB{name: 'on_loan_from_serie_a_side'}),
# (hoffenheim_ii:CLUB{name: 'hoffenheim_ii'}),
# (prior_to_joining:CLUB{name: 'prior_to_joining'}),
# (twelve_january_2013:DATE{name: '12_january_2013'}),
# (roda_jc_kerkrade:CLUB{name: 'roda_jc_kerkrade'}),
# (harry_nicholas_arter)-[:played_for]->(welling_united),
# (harry_nicholas_arter)-[:played_for]->(carlisle_united),
# (harry_nicholas_arter)-[:plays_as]->(defensive_midfielder),
# (harry_nicholas_arter)-[:played_for]->(charlton_athletic),
# (harry_nicholas_arter)-[:born]->(twenty_eight_december_1989),
# (harry_nicholas_arter)-[:played_for]->(bournemouth),
# (harry_nicholas_arter)-[:played_for]->(nottingham_forest);
#
#
#
# query_set_RE text nr 1:  {'(george_henry_ivor_baldock)-[:plays_for]->(sheffield_united)', '(harry_nicholas_arter)-[:played_for]->(welling_united)', '(george_henry_ivor_baldock)-[:plays_as]->(right_back)', '(harry_nicholas_arter)-[:played_for]->(carlisle_united)', '(harry_nicholas_arter)-[:plays_as]->(defensive_midfielder)', '(george_henry_ivor_baldock)-[:originates_from]->(england)', '(george_henry_ivor_baldock)-[:born]->(nine_march_1993)', '(harry_nicholas_arter)-[:played_for]->(charlton_athletic)', '(harry_nicholas_arter)-[:born]->(twenty_eight_december_1989)', '(harry_nicholas_arter)-[:played_for]->(bournemouth)', '(harry_nicholas_arter)-[:played_for]->(nottingham_forest)', '(george_henry_ivor_baldock)-[:played_for]->(milton_keynes_dons)', '(george_henry_ivor_baldock)-[:refers_to]->(baldock)'}
#
# cqlCreate text nr 1 CREATE
# (berke_ozer:PLAYER{name: 'berke_ozer'}),
# (aaron_james_ramsey:PLAYER{name: 'aaron_james_ramsey'}),
# (swansea_city:CLUB{name: 'swansea_city'}),
# (sixteen_august_2009:DATE{name: '16_august_2009'}),
# (daniel_powell:PLAYER{name: 'daniel_powell'}),
# (in_august_2010_career:CLUB{name: 'in_august_2010_career'}),
# (mansfield:CLUB{name: 'mansfield'}),
# (antonio:PLAYER{name: 'antonio'}),
# (twenty_five_august_2012:DATE{name: '25_august_2012'}),
# (kv_oostende:CLUB{name: 'kv_oostende'}),
# (wayne_robert_hennessey:PLAYER{name: 'wayne_robert_hennessey'}),
# (ivan_perisic:PLAYER{name: 'ivan_perisic'}),
# (twenty_five_march_2015:DATE{name: '25_march_2015'}),
# (arsenal:CLUB{name: 'arsenal'}),
# (hennesseys:PLAYER{name: 'hennesseys'}),
# (thirty_october_2021:DATE{name: '30_october_2021'}),
# (dynamo_moscow:CLUB{name: 'dynamo_moscow'}),
# (mke_ankaragucu:CLUB{name: 'mke_ankaragucu'}),
# (gateshead:CLUB{name: 'gateshead'}),
# (de_bruyne:PLAYER{name: 'de_bruyne'}),
# (twenty_one_november_1991:DATE{name: '21_november_1991'}),
# (sessegnon_helped_fulham:PLAYER{name: 'sessegnon_helped_fulham'}),
# (radu:PLAYER{name: 'radu'}),
# (stephane_sessegnon:PLAYER{name: 'stephane_sessegnon'}),
# (torino:CLUB{name: 'torino'}),
# (wrexham:CLUB{name: 'wrexham'}),
# (at_week_4_encounter_against:PLAYER{name: 'at_week_4_encounter_against'}),
# (twenty_seven_may_2016:DATE{name: '27_may_2016'}),
# (july_2010:DATE{name: 'july_2010'}),
# (clynebegan_his_career_at:CLUB{name: 'clynebegan_his_career_at'}),
# (fenerbahce:CLUB{name: 'fenerbahce'}),
# (danish:NATIONALITY{name: 'danish'}),
# (northern_ireland:COUNTRY{name: 'northern_ireland'}),
# (american:NATIONALITY{name: 'american'}),
# (dutch:NATIONALITY{name: 'dutch'}),
# (fifteen_december_1989:DATE{name: '15_december_1989'}),
# (ogbonna:PLAYER{name: 'ogbonna'}),
# (fourteen_april_1998:DATE{name: '14_april_1998'}),
# (viitorul:CLUB{name: 'viitorul'}),
# (cardiff_city:CLUB{name: 'cardiff_city'}),
# (west_bromwich_albion:CLUB{name: 'west_bromwich_albion'}),
# (colchester_united:CLUB{name: 'colchester_united'}),
# (fifteen_january_1994:DATE{name: '15_january_1994'}),
# (twenty_seven_september_2013:DATE{name: '27_september_2013'}),
# (fifteen_october_2022:DATE{name: '15_october_2022'}),
# (portugal:COUNTRY{name: 'portugal'}),
# (swindon_town:CLUB{name: 'swindon_town'}),
# (eleven_october_1988:DATE{name: '11_october_1988'}),
# (new_york_red_bulls:CLUB{name: 'new_york_red_bulls'}),
# (pascal_gross:PLAYER{name: 'pascal_gross'}),
# (tranmere:CLUB{name: 'tranmere'}),
# (leicester_city:CLUB{name: 'leicester_city'}),
# (southampton:CLUB{name: 'southampton'}),
# (burnley:CLUB{name: 'burnley'}),
# (andrei_radu:PLAYER{name: 'andrei_radu'}),
# (october_5_1987:DATE{name: 'october_5_1987'}),
# (in_a_4_0_win_against:CLUB{name: 'in_a_4-0_win_against'}),
# (twenty_nine_january_2016:DATE{name: '29_january_2016'}),
# (milners:PLAYER{name: 'milners'}),
# (england:COUNTRY{name: 'england'}),
# (werder_bremen:CLUB{name: 'werder_bremen'}),
# (burnleys:CLUB{name: 'burnleys'}),
# (ado:CLUB{name: 'ado'}),
# (nottingham_forest:CLUB{name: 'nottingham_forest'}),
# (alcorcon:CLUB{name: 'alcorcon'}),
# (remi_walter:PLAYER{name: 'remi_walter'}),
# (club_career:CLUB{name: 'club_career'}),
# (thomas_david_heaton:PLAYER{name: 'thomas_david_heaton'}),
# (romanian:NATIONALITY{name: 'romanian'}),
# (scunthorpe_united:CLUB{name: 'scunthorpe_united'}),
# (in_2014_he_moved_to:CLUB{name: 'in_2014_he_moved_to'}),
# (august_2010:DATE{name: 'august_2010'}),
# (in_july_2010_he_then_joined:CLUB{name: 'in_july_2010_he_then_joined'}),
# (beerschot:CLUB{name: 'beerschot'}),
# (doku:PLAYER{name: 'doku'}),
# (brentford:CLUB{name: 'brentford'}),
# (chicago_fire:CLUB{name: 'chicago_fire'}),
# (dawson:PLAYER{name: 'dawson'}),
# (forward:POSITION{name: 'forward'}),
# (christopher_paul_basham:PLAYER{name: 'christopher_paul_basham'}),
# (northampton_town:CLUB{name: 'northampton_town'}),
# (mark_maria_hubertus_flekken:PLAYER{name: 'mark_maria_hubertus_flekken'}),
# (against:CLUB{name: 'against'}),
# (lenglet:PLAYER{name: 'lenglet'}),
# (twenty_seven_may_2002:DATE{name: '27_may_2002'}),
# (scotland:COUNTRY{name: 'scotland'}),
# (newcastles:CLUB{name: 'newcastles'}),
# (sligo_rovers:CLUB{name: 'sligo_rovers'}),
# (kaminski:PLAYER{name: 'kaminski'}),
# (avellino:CLUB{name: 'avellino'}),
# (twelve_may_1987:DATE{name: '12_may_1987'}),
# (fifteen_november_2018:DATE{name: '15_november_2018'}),
# (thomas_alun_lockyer:PLAYER{name: 'thomas_alun_lockyer'}),
# (manuel_obafemi_akanji:PLAYER{name: 'manuel_obafemi_akanji'}),
# (kaminskis:PLAYER{name: 'kaminskis'}),
# (carsonjoined_the:CLUB{name: 'carsonjoined_the'}),
# (gosport_borough:CLUB{name: 'gosport_borough'}),
# (brother_steven:PLAYER{name: 'brother_steven'}),
# (nuova_cassino:CLUB{name: 'nuova_cassino'}),
# (sheffield_united:CLUB{name: 'sheffield_united'}),
# (christian_dannemann_eriksen:PLAYER{name: 'christian_dannemann_eriksen'}),
# (ellis_harrison:PLAYER{name: 'ellis_harrison'}),
# (switzerland:COUNTRY{name: 'switzerland'}),
# (olympique_lyonnais:CLUB{name: 'olympique_lyonnais'}),
# (bayern_munich:CLUB{name: 'bayern_munich'}),
# (english:NATIONALITY{name: 'english'}),
# (goalkeeper:POSITION{name: 'goalkeeper'}),
# (barcelona:CLUB{name: 'barcelona'}),
# (st_catherines:CLUB{name: 'st_catherines'}),
# (louise_dier:PLAYER{name: 'louise_dier'}),
# (drc:COUNTRY{name: 'drc'}),
# (real_madrid_castilla:CLUB{name: 'real_madrid_castilla'}),
# (ipswich_town:CLUB{name: 'ipswich_town'}),
# (yeovil_town:CLUB{name: 'yeovil_town'}),
# (august_2011:DATE{name: 'august_2011'}),
# (linda_arter:PLAYER{name: 'linda_arter'}),
# (cork:PLAYER{name: 'cork'}),
# (doucoureplays_for_the:COUNTRY{name: 'doucoureplays_for_the'}),
# (madrid:CLUB{name: 'madrid'}),
# (center_back:POSITION{name: 'center_back'}),
# (annie:PLAYER{name: 'annie'}),
# (primarily_a:POSITION{name: 'primarily_a'}),
# (twenty_six_december_1990:DATE{name: '26_december_1990'}),
# (basham_returned:PLAYER{name: 'basham_returned'}),
# (rodriguez:PLAYER{name: 'rodriguez'}),
# (seventeen_june_1995:DATE{name: '17_june_1995'}),
# (ten_may_1988:DATE{name: '10_may_1988'}),
# (two_february_1989:DATE{name: '2_february_1989'}),
# (crystal_palace:CLUB{name: 'crystal_palace'}),
# (august_8_1997:DATE{name: 'august_8_1997'}),
# (striker:POSITION{name: 'striker'}),
# (right_midfielder:POSITION{name: 'right_midfielder'}),
# (konyaspor:CLUB{name: 'konyaspor'}),
# (chamberscould_also_play_at:POSITION{name: 'chamberscould_also_play_at'}),
# (he_can_also_play_as_a:POSITION{name: 'he_can_also_play_as_a'}),
# (wimbledon:CLUB{name: 'wimbledon'}),
# (genoa:CLUB{name: 'genoa'}),
# (lockyer:PLAYER{name: 'lockyer'}),
# (midfielder:POSITION{name: 'midfielder'}),
# (belgian:NATIONALITY{name: 'belgian'}),
# (germinal_beerschot:CLUB{name: 'germinal_beerschot'}),
# (rkvv_wdz:CLUB{name: 'rkvv_wdz'}),
# (charleroi:CLUB{name: 'charleroi'}),
# (merseyside:CLUB{name: 'merseyside'}),
# (ibv:CLUB{name: 'ibv'}),
# (june_2021:DATE{name: 'june_2021'}),
# (celtics:CLUB{name: 'celtics'}),
# (swindon:CLUB{name: 'swindon'}),
# (dalry_rovers:CLUB{name: 'dalry_rovers'}),
# (left_winger:POSITION{name: 'left_winger'}),
# (st_dominic:CLUB{name: 'st_dominic'}),
# (zaroury:PLAYER{name: 'zaroury'}),
# (charlie_collins:PLAYER{name: 'charlie_collins'}),
# (middlesbrough_two:CLUB{name: 'middlesbrough_two'}),
# (in_2021:CLUB{name: 'in_2021'}),
# (sochaux:CLUB{name: 'sochaux'}),
# (oh_leuven:CLUB{name: 'oh_leuven'}),
# (one_january_1993:DATE{name: '1_january_1993'}),
# (brighton_amp:CLUB{name: 'brighton_amp'}),
# (anass_zaroury:PLAYER{name: 'anass_zaroury'}),
# (denizlispor_which_fenerbahce:PLAYER{name: 'denizlispor_which_fenerbahce'}),
# (sao_paulo:CLUB{name: 'sao_paulo'}),
# (one_fc_saarbrucken:CLUB{name: '1_fc_saarbrucken'}),
# (twenty_two_september_1984:DATE{name: '22_september_1984'}),
# (st_albans_city:CLUB{name: 'st_albans_city'}),
# (on:CLUB{name: 'on'}),
# (carson:PLAYER{name: 'carson'}),
# (carlisle_united:CLUB{name: 'carlisle_united'}),
# (daniel_william_john_ings:PLAYER{name: 'daniel_william_john_ings'}),
# (twenty_nine_january_2022:DATE{name: '29_january_2022'}),
# (limburg:CLUB{name: 'limburg'}),
# (parma:CLUB{name: 'parma'}),
# (twenty_three_july_1992:DATE{name: '23_july_1992'}),
# (italian:NATIONALITY{name: 'italian'}),
# (seamus_coleman:PLAYER{name: 'seamus_coleman'}),
# (portsmouth:CLUB{name: 'portsmouth'}),
# (nineteen_july_1995:DATE{name: '19_july_1995'}),
# (sessegnon:PLAYER{name: 'sessegnon'}),
# (he_plays_for_the:COUNTRY{name: 'he_plays_for_the'}),
# (chelsea:CLUB{name: 'chelsea'}),
# (rangers:CLUB{name: 'rangers'}),
# (ings:PLAYER{name: 'ings'}),
# (june_2013:DATE{name: 'june_2013'}),
# (barnsley:CLUB{name: 'barnsley'}),
# (wolfsburg:CLUB{name: 'wolfsburg'}),
# (robinson:PLAYER{name: 'robinson'}),
# (one_december_2019:DATE{name: '1_december_2019'}),
# (ben_gannon_doak:PLAYER{name: 'ben_gannon_doak'}),
# (royal_antwerp:CLUB{name: 'royal_antwerp'}),
# (athletic:CLUB{name: 'athletic'}),
# (he_began_his_career_with:CLUB{name: 'he_began_his_career_with'}),
# (fifteen_april_1986:DATE{name: '15_april_1986'}),
# (italy:COUNTRY{name: 'italy'}),
# (right_back:POSITION{name: 'right_back'}),
# (july_2012:DATE{name: 'july_2012'}),
# (two_november_2006:DATE{name: '2_november_2006'}),
# (coleman:PLAYER{name: 'coleman'}),
# (motherwell:CLUB{name: 'motherwell'}),
# (finland:COUNTRY{name: 'finland'}),
# (bury:CLUB{name: 'bury'}),
# (three_january_2010:DATE{name: '3_january_2010'}),
# (amine_harit:PLAYER{name: 'amine_harit'}),
# (cremonese:CLUB{name: 'cremonese'}),
# (hennessey:PLAYER{name: 'hennessey'}),
# (in_january_2022_career:CLUB{name: 'in_january_2022_career'}),
# (september_2022:DATE{name: 'september_2022'}),
# (newcastle:CLUB{name: 'newcastle'}),
# (cardiff:CLUB{name: 'cardiff'}),
# (oud_heverlee_leuven:CLUB{name: 'oud_heverlee_leuven'}),
# (evertons:CLUB{name: 'evertons'}),
# (heaton:PLAYER{name: 'heaton'}),
# (twenty_three_february_1992:DATE{name: '23_february_1992'}),
# (ritchie:PLAYER{name: 'ritchie'}),
# (six_december_2020:DATE{name: '6_december_2020'}),
# (timothy_michael_krul:PLAYER{name: 'timothy_michael_krul'}),
# (ionut_andrei_radu:PLAYER{name: 'ionut_andrei_radu'}),
# (right_winger:POSITION{name: 'right_winger'}),
# (bristol_rovers:CLUB{name: 'bristol_rovers'}),
# (tubantia_borgerhout:PLAYER{name: 'tubantia_borgerhout'}),
# (clermont:CLUB{name: 'clermont'}),
# (jay_enrique_rodriguez:PLAYER{name: 'jay_enrique_rodriguez'}),
# (brightons:CLUB{name: 'brightons'}),
# (croatian:NATIONALITY{name: 'croatian'}),
# (radoslaw_murawski:PLAYER{name: 'radoslaw_murawski'}),
# (spanish:NATIONALITY{name: 'spanish'}),
# (fluminense:CLUB{name: 'fluminense'}),
# (centre_back:POSITION{name: 'centre_back'}),
# (blackburn_rovers:CLUB{name: 'blackburn_rovers'}),
# (eighteen_may_2000:DATE{name: '18_may_2000'}),
# (ayr_united:CLUB{name: 'ayr_united'}),
# (kevin_de_bruyne:PLAYER{name: 'kevin_de_bruyne'}),
# (greece:COUNTRY{name: 'greece'}),
# (full_back:POSITION{name: 'full_back'}),
# (twelve_june_2021:DATE{name: '12_june_2021'}),
# (silva:PLAYER{name: 'silva'}),
# (five_april_1991:DATE{name: '5_april_1991'}),
# (paddy:CLUB{name: 'paddy'}),
# (twenty_eight_may_1997:DATE{name: '28_may_1997'}),
# (wigan:CLUB{name: 'wigan'}),
# (dorchester_town:CLUB{name: 'dorchester_town'}),
# (ten_september_1989:DATE{name: '10_september_1989'}),
# (twenty_three_may_1988:DATE{name: '23_may_1988'}),
# (three_april_1988:DATE{name: '3_april_1988'}),
# (ireland:COUNTRY{name: 'ireland'}),
# (beninese:NATIONALITY{name: 'beninese'}),
# (derby_county:CLUB{name: 'derby_county'}),
# (arter:PLAYER{name: 'arter'}),
# (sixteen_november_2022:DATE{name: '16_november_2022'}),
# (rovers:CLUB{name: 'rovers'}),
# (fc_lugano:CLUB{name: 'fc_lugano'}),
# (stuttgarter_kickers_ii:CLUB{name: 'stuttgarter_kickers_ii'}),
# (uk:COUNTRY{name: 'uk'}),
# (evans:PLAYER{name: 'evans'}),
# (anderlecht:CLUB{name: 'anderlecht'}),
# (real_madrid:CLUB{name: 'real_madrid'}),
# (lloris:PLAYER{name: 'lloris'}),
# (three_september_1985:DATE{name: '3_september_1985'}),
# (blackpool:CLUB{name: 'blackpool'}),
# (sheffield_wednesday:CLUB{name: 'sheffield_wednesday'}),
# (brazil:COUNTRY{name: 'brazil'}),
# (milner:PLAYER{name: 'milner'}),
# (wales:COUNTRY{name: 'wales'}),
# (fc_porto:CLUB{name: 'fc_porto'}),
# (charlton:CLUB{name: 'charlton'}),
# (saved_a_penalty_shot_by:PLAYER{name: 'saved_a_penalty_shot_by'}),
# (attacking_midfielder_or:POSITION{name: 'attacking_midfielder_or'}),
# (ederson:PLAYER{name: 'ederson'}),
# (spain:COUNTRY{name: 'spain'}),
# (signed_for_his_local_clu:PLAYER{name: 'signed_for_his_local_clu'}),
# (george_henry_ivor_baldock:PLAYER{name: 'george_henry_ivor_baldock'}),
# (malian:NATIONALITY{name: 'malian'}),
# (doucoure:PLAYER{name: 'doucoure'}),
# (antonee_robinson:PLAYER{name: 'antonee_robinson'}),
# (or:POSITION{name: 'or'}),
# (fleetwood_town:CLUB{name: 'fleetwood_town'}),
# (pablo_sarabia_garcia:PLAYER{name: 'pablo_sarabia_garcia'}),
# (seventeen_march_2014:DATE{name: '17_march_2014'}),
# (left_back:POSITION{name: 'left_back'}),
# (wolverhampton_wanderers:CLUB{name: 'wolverhampton_wanderers'}),
# (french:NATIONALITY{name: 'french'}),
# (bursaspor_of_turkey:COUNTRY{name: 'bursaspor_of_turkey'}),
# (nineteen_august_2019:DATE{name: '19_august_2019'}),
# (st_johnstone:CLUB{name: 'st_johnstone'}),
# (ogbonnasigned_for:CLUB{name: 'ogbonnasigned_for'}),
# (sporting_cp:CLUB{name: 'sporting_cp'}),
# (october_2020:DATE{name: 'october_2020'}),
# (fc_winterthur:CLUB{name: 'fc_winterthur'}),
# (harry_nicholas_arter:PLAYER{name: 'harry_nicholas_arter'}),
# (leeds_youth:CLUB{name: 'leeds_youth'}),
# (six_may_1990:DATE{name: '6_may_1990'}),
# (accrington_stanley:CLUB{name: 'accrington_stanley'}),
# (rennes:CLUB{name: 'rennes'}),
# (twenty_eight_march_1990:DATE{name: '28_march_1990'}),
# (united_states:COUNTRY{name: 'united_states'}),
# (granada_cf:CLUB{name: 'granada_cf'}),
# (harun_tekin:PLAYER{name: 'harun_tekin'}),
# (twenty_eight_september_1985:DATE{name: '28_september_1985'}),
# (akanji:PLAYER{name: 'akanji'}),
# (serdar:NATIONALITY{name: 'serdar'}),
# (james_philip_milner:PLAYER{name: 'james_philip_milner'}),
# (twenty_six_august_2020:DATE{name: '26_august_2020'}),
# (may_2013:DATE{name: 'may_2013'}),
# (moroccan:NATIONALITY{name: 'moroccan'}),
# (city:CLUB{name: 'city'}),
# (new_hartley:CLUB{name: 'new_hartley'}),
# (irish:NATIONALITY{name: 'irish'}),
# (seven_february_2008:DATE{name: '7_february_2008'}),
# (krul:PLAYER{name: 'krul'}),
# (wycombe_wanderers:CLUB{name: 'wycombe_wanderers'}),
# (brighton:CLUB{name: 'brighton'}),
# (he_represents_the:COUNTRY{name: 'he_represents_the'}),
# (randolph:PLAYER{name: 'randolph'}),
# (defender:POSITION{name: 'defender'}),
# (michael_melka:PLAYER{name: 'michael_melka'}),
# (seven_november_2000:DATE{name: '7_november_2000'}),
# (bournemouth:CLUB{name: 'bournemouth'}),
# (bolton:CLUB{name: 'bolton'}),
# (brazilian:NATIONALITY{name: 'brazilian'}),
# (hull_city:CLUB{name: 'hull_city'}),
# (nathaniel_edwin_clyne:PLAYER{name: 'nathaniel_edwin_clyne'}),
# (ado_den_haag:CLUB{name: 'ado_den_haag'}),
# (bayindir:PLAYER{name: 'bayindir'}),
# (four_march_2017:DATE{name: '4_march_2017'}),
# (and:CLUB{name: 'and'}),
# (villa:CLUB{name: 'villa'}),
# (sunderland:CLUB{name: 'sunderland'}),
# (manchester_city:CLUB{name: 'manchester_city'}),
# (rochdale_st:CLUB{name: 'rochdale_st'}),
# (in_2015_after:CLUB{name: 'in_2015_after'}),
# (hugo_hadrien_dominique_lloris:PLAYER{name: 'hugo_hadrien_dominique_lloris'}),
# (west_ham_united:CLUB{name: 'west_ham_united'}),
# (cresswell:PLAYER{name: 'cresswell'}),
# (everton:CLUB{name: 'everton'}),
# (eleven_february_2007:DATE{name: '11_february_2007'}),
# (thirty_august_2022:DATE{name: '30_august_2022'}),
# (against_both:COUNTRY{name: 'against_both'}),
# (twenty_two_september_2011:DATE{name: '22_september_2011'}),
# (ipswich:CLUB{name: 'ipswich'}),
# (ac_arles_avignon:CLUB{name: 'ac_arles_avignon'}),
# (dundee_united:CLUB{name: 'dundee_united'}),
# (turkish:NATIONALITY{name: 'turkish'}),
# (norwich_city:CLUB{name: 'norwich_city'}),
# (january_2023:DATE{name: 'january_2023'}),
# (january_2019:DATE{name: 'january_2019'}),
# (twenty_three_october_1992:DATE{name: '23_october_1992'}),
# (twenty_eight_june_1991:DATE{name: '28_june_1991'}),
# (july_2020:DATE{name: 'july_2020'}),
# (fifteen_june_1991:DATE{name: '15_june_1991'}),
# (twenty_july_1988:DATE{name: '20_july_1988'}),
# (twenty_five_november_2018:DATE{name: '25_november_2018'}),
# (defensive_midfielder:POSITION{name: 'defensive_midfielder'}),
# (leeds_united:CLUB{name: 'leeds_united'}),
# (milner_went:PLAYER{name: 'milner_went'}),
# (steve_harper:PLAYER{name: 'steve_harper'}),
# (july_2008:DATE{name: 'july_2008'}),
# (in_2016_he_played_for:CLUB{name: 'in_2016_he_played_for'}),
# (milton_keynes_dons:CLUB{name: 'milton_keynes_dons'}),
# (fc_basel:CLUB{name: 'fc_basel'}),
# (dier:PLAYER{name: 'dier'}),
# (jonathan_grant_evans:PLAYER{name: 'jonathan_grant_evans'}),
# (second_striker_or:POSITION{name: 'second_striker_or'}),
# (rsc_anderlecht:CLUB{name: 'rsc_anderlecht'}),
# (twenty_eight_december_1989:DATE{name: '28_december_1989'}),
# (central_midfielder:POSITION{name: 'central_midfielder'}),
# (three_may_2012:DATE{name: '3_may_2012'}),
# (twenty_six_december_2021:DATE{name: '26_december_2021'}),
# (vfl_wolfsburg:CLUB{name: 'vfl_wolfsburg'}),
# (lallana:PLAYER{name: 'lallana'}),
# (fc_ingolstadt:CLUB{name: 'fc_ingolstadt'}),
# (seventeen_march_1988:DATE{name: '17_march_1988'}),
# (beat:CLUB{name: 'beat'}),
# (kvc_olympic_deurne:CLUB{name: 'kvc_olympic_deurne'}),
# (formerly:PLAYER{name: 'formerly'}),
# (netherlands:COUNTRY{name: 'netherlands'}),
# (hajduk_split:CLUB{name: 'hajduk_split'}),
# (milan:CLUB{name: 'milan'}),
# (twenty_four_january_1987:DATE{name: '24_january_1987'}),
# (twenty_three_august_2021:DATE{name: '23_august_2021'}),
# (forster:PLAYER{name: 'forster'}),
# (darren_edward_andrew_randolph:PLAYER{name: 'darren_edward_andrew_randolph'}),
# (ingolstadt:CLUB{name: 'ingolstadt'}),
# (borussia_dortmund:CLUB{name: 'borussia_dortmund'}),
# (baldock:PLAYER{name: 'baldock'}),
# (pundits:PLAYER{name: 'pundits'}),
# (eight_july_2019:DATE{name: '8_july_2019'}),
# (july_2019:DATE{name: 'july_2019'}),
# (perisic:PLAYER{name: 'perisic'}),
# (liverpool:CLUB{name: 'liverpool'}),
# (royal_excel_mouscron:CLUB{name: 'royal_excel_mouscron'}),
# (eleven_may_1992:DATE{name: '11_may_1992'}),
# (northampton:CLUB{name: 'northampton'}),
# (watford:CLUB{name: 'watford'}),
# (nine_november_2022:DATE{name: '9_november_2022'}),
# (port_vale:CLUB{name: 'port_vale'}),
# (palace:CLUB{name: 'palace'}),
# (german:NATIONALITY{name: 'german'}),
# (albion:CLUB{name: 'albion'}),
# (one_thousand_eight_hundred_and_ninety_nine_hoffenheim:CLUB{name: '1899_hoffenheim'}),
# (left_midfielder:POSITION{name: 'left_midfielder'}),
# (four_january_1986:DATE{name: '4_january_1986'}),
# (gross:CLUB{name: 'gross'}),
# (alemannia_aachen:CLUB{name: 'alemannia_aachen'}),
# (january_2011:DATE{name: 'january_2011'}),
# (he_went_on_to_represent:CLUB{name: 'he_went_on_to_represent'}),
# (august_2019:DATE{name: 'august_2019'}),
# (stoke_city:CLUB{name: 'stoke_city'}),
# (may_2003:DATE{name: 'may_2003'}),
# (daniel_johnson_burn:PLAYER{name: 'daniel_johnson_burn'}),
# (central_defender:POSITION{name: 'central_defender'}),
# (three_december_1994:DATE{name: '3_december_1994'}),
# (three_january_1988:DATE{name: '3_january_1988'}),
# (paris_saint_germain:CLUB{name: 'paris_saint_germain'}),
# (twelve_march_2013:DATE{name: '12_march_2013'}),
# (dunk:PLAYER{name: 'dunk'}),
# (alan_shearer:PLAYER{name: 'alan_shearer'}),
# (fifteen_april_2015:DATE{name: '15_april_2015'}),
# (eighteen_october_2008:DATE{name: '18_october_2008'}),
# (january_2017:DATE{name: 'january_2017'}),
# (sint_truiden:PLAYER{name: 'sint_truiden'}),
# (he_played_for:CLUB{name: 'he_played_for'}),
# (aaron_william_cresswell:PLAYER{name: 'aaron_william_cresswell'}),
# (welsh:NATIONALITY{name: 'welsh'}),
# (made_ten_appearances_for_the:PLAYER{name: 'made_ten_appearances_for_the'}),
# (ogc_nice:CLUB{name: 'ogc_nice'}),
# (inter_milan:CLUB{name: 'inter_milan'}),
# (newcastle_united:CLUB{name: 'newcastle_united'}),
# (twenty_nine_july_1989:DATE{name: '29_july_1989'}),
# (eleven_november_2005:DATE{name: '11_november_2005'}),
# (zulte_waregem:CLUB{name: 'zulte_waregem'}),
# (selhurst:CLUB{name: 'selhurst'}),
# (one_february_2021:DATE{name: '1_february_2021'}),
# (fc_steaua_bucuresti:CLUB{name: 'fc_steaua_bucuresti'}),
# (he_broke_into:CLUB{name: 'he_broke_into'}),
# (sarabia:PLAYER{name: 'sarabia'}),
# (made_his_debut_for_the:PLAYER{name: 'made_his_debut_for_the'}),
# (twenty_six_december_1986:DATE{name: '26_december_1986'}),
# (karlsruher_sc:CLUB{name: 'karlsruher_sc'}),
# (heywood_st_james:CLUB{name: 'heywood_st_james'}),
# (attacking_midfielder:POSITION{name: 'attacking_midfielder'}),
# (hereford_united:CLUB{name: 'hereford_united'}),
# (france:COUNTRY{name: 'france'}),
# (rochdale:CLUB{name: 'rochdale'}),
# (eriksen:PLAYER{name: 'eriksen'}),
# (st_louis_scott_gallagher:CLUB{name: 'st_louis_scott_gallagher'}),
# (greuther_furth:CLUB{name: 'greuther_furth'}),
# (celtic:CLUB{name: 'celtic'}),
# (and_a:POSITION{name: 'and_a'}),
# (stafford_rangers:CLUB{name: 'stafford_rangers'}),
# (porto:CLUB{name: 'porto'}),
# (belgium:COUNTRY{name: 'belgium'}),
# (adalberto_penaranda:PLAYER{name: 'adalberto_penaranda'}),
# (before_transferring_to:CLUB{name: 'before_transferring_to'}),
# (nine_may_1992:DATE{name: '9_may_1992'}),
# (queens_park_rangers:CLUB{name: 'queens_park_rangers'}),
# (casemiro:PLAYER{name: 'casemiro'}),
# (march_2022:DATE{name: 'march_2022'}),
# (twenty_six_january_2013:DATE{name: '26_january_2013'}),
# (moved_to_the_2_bundesliga_clu:PLAYER{name: 'moved_to_the_2_bundesliga_clu'}),
# (jack_frank_porteous_cork:PLAYER{name: 'jack_frank_porteous_cork'}),
# (twenty_five_june_1989:DATE{name: '25_june_1989'}),
# (chambers:PLAYER{name: 'chambers'}),
# (one_february_2016:DATE{name: '1_february_2016'}),
# (daniel:PLAYER{name: 'daniel'}),
# (wigan_athletic:CLUB{name: 'wigan_athletic'}),
# (croatia:COUNTRY{name: 'croatia'}),
# (welling_united:CLUB{name: 'welling_united'}),
# (blyth_town:CLUB{name: 'blyth_town'}),
# (tottenham_hotspur:CLUB{name: 'tottenham_hotspur'}),
# (shay_given:PLAYER{name: 'shay_given'}),
# (afc_bournemouth:CLUB{name: 'afc_bournemouth'}),
# (swiss:NATIONALITY{name: 'swiss'}),
# (five_october_2020:DATE{name: '5_october_2020'}),
# (ream:PLAYER{name: 'ream'}),
# (flekken:PLAYER{name: 'flekken'}),
# (ac_milan:CLUB{name: 'ac_milan'}),
# (two_may_2009:DATE{name: '2_may_2009'}),
# ...
# (james_philip_milner)-[:refers_to]->(milner),
# (ivan_perisic)-[:plays_as]->(left_wing_back),
# (timothy_michael_ream)-[:born]->(october_5_1987),
# (daniel_johnson_burn)-[:played_for]->(yeovil_town),
# (carlos_henrique_casimiro)-[:plays_as]->(defensive_midfielder),
# (adam_david_lallana)-[:has_nationality]->(english),
# (hugo_hadrien_dominique_lloris)-[:played_for]->(milan),
# (lewis_carl_dunk)-[:played_for]->(brightons),
# (timothy_michael_krul)-[:plays_for]->(luton_town),
# (mark_maria_hubertus_flekken)-[:plays_for]->(brentford),
# (michail_gregory_antonio)-[:played_for]->(colchester_united),
# (daniel_johnson_burn)-[:played_for]->(fulham),
# (fraser_gerard_forster)-[:has_nationality]->(english),
# (jonathan_grant_evans)-[:played_for]->(sunderland),
# (eric_jeremy_edgar_dier)-[:plays_as]->(defensive_midfielder),
# (james_philip_milner)-[:born]->(four_january_1986),
# (christopher_paul_basham)-[:has_nationality]->(english),
# (wayne_robert_hennessey)-[:refers_to]->(hennesseys),
# (eric_jeremy_edgar_dier)-[:plays_for]->(tottenham_hotspur),
# (christian_dannemann_eriksen)-[:refers_to]->(eriksen),
# (harry_nicholas_arter)-[:played_for]->(carlisle_united),
# (kouassi_ryan_sessegnon)-[:plays_as]->(left_midfielder),
# (craig_dawson)-[:plays_for]->(wolverhampton_wanderers),
# (scott_paul_carson)-[:plays_for]->(manchester_city),
# (daniel_johnson_burn)-[:born]->(nine_may_1992),
# (nathaniel_edwin_clyne)-[:played_for]->(crystal_palace),
# (altay_bayindir)-[:played_for]->(mke_ankaragucu),
# (pascal_gross)-[:plays_as]->(right_back),
# (eric_jeremy_edgar_dier)-[:born]->(fifteen_january_1994),
# (carlos_henrique_casimiro)-[:born]->(twenty_three_february_1992),
# (wayne_robert_hennessey)-[:has_nationality]->(welsh),
# (thomas_cairney)-[:played_for]->(blackburn_rovers),
# (jay_enrique_rodriguez)-[:has_nationality]->(english),
# (hugo_hadrien_dominique_lloris)-[:plays_for]->(tottenham_hotspur),
# (luke_chambers)-[:played_for]->(nottingham_forest),
# (timothy_michael_ream)-[:plays_as]->(left_back),
# (aaron_james_ramsey)-[:played_for]->(cardiff_city),
# (ben_gannon_doak)-[:played_for]->(celtic),
# (pablo_sarabia_garcia)-[:plays_as]->(attacking_midfielder),
# (sint_truiden)-[:born]->(twenty_five_november_2018),
# (anass_zaroury)-[:originates_from]->(belgium),
# (jack_frank_porteous_cork)-[:plays_as]->(midfielder),
# (seamus_coleman)-[:has_nationality]->(irish),
# (luke_chambers)-[:plays_as]->(centre_back),
# (timothy_michael_krul)-[:played_for]->(newcastle_united),
# (seamus_coleman)-[:played_for]->(st_catherines),
# (timothy_michael_krul)-[:has_nationality]->(dutch),
# (jack_frank_porteous_cork)-[:has_nationality]->(english),
# (thomas_kaminski)-[:plays_for]->(luton_town),
# (aaron_james_ramsey)-[:has_nationality]->(welsh),
# (christian_dannemann_eriksen)-[:plays_for]->(manchester_united),
# (thiago_emiliano_da_silva)-[:plays_as]->(centre_back),
# (kevin_de_bruyne)-[:plays_as]->(midfielder),
# (scott_paul_carson)-[:plays_as]->(goalkeeper),
# (luke_chambers)-[:played_for]->(ipswich_town),
# (manuel_obafemi_akanji)-[:played_for]->(fifteen_april_2015),
# (aaron_william_cresswell)-[:born]->(fifteen_december_1989),
# (jack_frank_porteous_cork)-[:played_for]->(scunthorpe_united),
# (carlos_henrique_casimiro)-[:played_for]->(sao_paulo),
# (pascal_gross)-[:played_for]->(gross),
# (nathaniel_edwin_clyne)-[:played_for]->(liverpool),
# (carlos_henrique_casimiro)-[:plays_as]->(midfielder),
# (matthew_thomas_ritchie)-[:plays_for]->(newcastle_united),
# (hugo_hadrien_dominique_lloris)-[:has_nationality]->(french),
# (aaron_james_ramsey)-[:born]->(twenty_six_december_1990),
# (antonee_robinson)-[:played_for]->(everton),
# (fraser_gerard_forster)-[:played_for]->(norwich_city),
# (obinze_angelo_ogbonna)-[:plays_as]->(centre_back),
# (daniel_johnson_burn)-[:has_nationality]->(english),
# (ionut_andrei_radu)-[:born]->(twenty_eight_may_1997),
# (seamus_coleman)-[:plays_for]->(everton),
# (craig_dawson)-[:played_for]->(bolton_wanderers),
# (jack_frank_porteous_cork)-[:plays_for]->(burnley),
# (dier)-[:plays_as]->(defensive_midfielder),
# (thomas_cairney)-[:born]->(twenty_january_1991),
# (antonee_robinson)-[:plays_for]->(fulham),
# (hugo_hadrien_dominique_lloris)-[:born]->(twenty_six_december_1986),
# (daniel_william_john_ings)-[:played_for]->(afc_bournemouth),
# (fraser_gerard_forster)-[:plays_as]->(goalkeeper),
# (adam_david_lallana)-[:played_for]->(bournemouth),
# (harry_nicholas_arter)-[:plays_as]->(defensive_midfielder),
# (anass_zaroury)-[:played_for]->(lommel),
# (lewis_carl_dunk)-[:played_for]->(bristol_city),
# (george_henry_ivor_baldock)-[:plays_for]->(sheffield_united),
# (thomas_david_heaton)-[:has_nationality]->(english),
# (scott_paul_carson)-[:has_nationality]->(english),
# (thomas_alun_lockyer)-[:played_for]->(radyr_rangers),
# (kouassi_ryan_sessegnon)-[:has_nationality]->(english),
# (anass_zaroury)-[:refers_to]->(zaroury),
# (jack_frank_porteous_cork)-[:played_for]->(burnley),
# (abdoulaye_doucoure)-[:plays_for]->(everton),
# (ivan_perisic)-[:played_for]->(hajduk_split),
# (ivan_perisic)-[:plays_as]->(left_winger),
# (daniel_william_john_ings)-[:played_for]->(southampton),
# (luke_chambers)-[:plays_as]->(defender),
# (aaron_william_cresswell)-[:plays_for]->(west_ham_united),
# (abdoulaye_doucoure)-[:born]->(one_january_1993),
# (christopher_paul_basham)-[:played_for]->(bolton_wanderers),
# (scott_paul_carson)-[:refers_to]->(carson),
# (ionut_andrei_radu)-[:refers_to]->(radu),
# (harry_nicholas_arter)-[:played_for]->(bournemouth),
# (darren_edward_andrew_randolph)-[:born]->(twelve_may_1987),
# (lewis_carl_dunk)-[:born]->(twenty_one_november_1991),
# (george_henry_ivor_baldock)-[:plays_as]->(right_back),
# (scott_paul_carson)-[:played_for]->(leeds_united),
# (kevin_de_bruyne)-[:refers_to]->(pundits),
# (abdoulaye_doucoure)-[:plays_as]->(central_midfielder),
# (christian_dannemann_eriksen)-[:born]->(fourteen_february_1992),
# (ben_gannon_doak)-[:has_nationality]->(scottish),
# (matthew_thomas_ritchie)-[:refers_to]->(ritchie),
# (thomas_kaminski)-[:played_for]->(germinal_beerschot),
# (christopher_paul_basham)-[:born]->(twenty_july_1988),
# (timothy_michael_ream)-[:plays_as]->(center_back),
# (george_henry_ivor_baldock)-[:originates_from]->(england),
# (aaron_james_ramsey)-[:played_for]->(arsenal),
# (timothy_michael_krul)-[:plays_as]->(goalkeeper),
# (matthew_thomas_ritchie)-[:played_for]->(newcastle_united),
# (ivan_perisic)-[:has_nationality]->(croatian),
# (carlos_henrique_casimiro)-[:plays_for]->(manchester_united),
# (daniel_william_john_ings)-[:has_nationality]->(english),
# (altay_bayindir)-[:plays_for]->(fenerbahce),
# (obinze_angelo_ogbonna)-[:played_for]->(july_2013),
# (eric_jeremy_edgar_dier)-[:plays_as]->(right_back),
# (tottenham_hotspur)-[:played_for]->(inter_milan),
# (harry_nicholas_arter)-[:played_for]->(welling_united),
# (nathaniel_edwin_clyne)-[:played_for]->(southampton),
# (thomas_david_heaton)-[:played_for]->(swindon_town),
# (ionut_andrei_radu)-[:refers_to]->(andrei_radu),
# (altay_bayindir)-[:has_nationality]->(turkish),
# (thomas_alun_lockyer)-[:refers_to]->(lockyer),
# (timothy_michael_ream)-[:has_nationality]->(american),
# (fraser_gerard_forster)-[:played_for]->(rovers),
# (eric_jeremy_edgar_dier)-[:has_nationality]->(english),
# (lewis_carl_dunk)-[:played_for]->(brighton),
# (daniel_johnson_burn)-[:played_for]->(darlington),
# (harry_nicholas_arter)-[:played_for]->(charlton_athletic),
# (harry_nicholas_arter)-[:played_for]->(nottingham_forest),
# (pascal_gross)-[:has_nationality]->(german),
# (daniel_william_john_ings)-[:played_for]->(dorchester_town),
# (harun_tekin)-[:born]->(nineteen_august_2019),
# (christopher_paul_basham)-[:played_for]->(newcastle_united),
# (pablo_sarabia_garcia)-[:born]->(eleven_may_1992),
# (thomas_david_heaton)-[:played_for]->(manchester_united),
# (george_henry_ivor_baldock)-[:born]->(nine_march_1993),
# (craig_dawson)-[:played_for]->(radcliffe_borough),
# (matthew_thomas_ritchie)-[:played_for]->(bournemouth),
# (altay_bayindir)-[:born]->(fourteen_april_1998),
# (anass_zaroury)-[:plays_as]->(winger),
# (altay_bayindir)-[:refers_to]->(bayindir),
# (wayne_robert_hennessey)-[:played_for]->(crystal_palace),
# (thomas_cairney)-[:plays_for]->(fulham),
# (thomas_david_heaton)-[:played_for]->(queens_park_rangers),
# (kouassi_ryan_sessegnon)-[:played_for]->(fulham),
# (fraser_gerard_forster)-[:plays_for]->(tottenham_hotspur),
# (jack_frank_porteous_cork)-[:played_for]->(southampton),
# (wayne_robert_hennessey)-[:plays_for]->(nottingham_forest),
# (thomas_cairney)-[:plays_as]->(attacking_midfielder),
# (thomas_david_heaton)-[:played_for]->(royal_antwerp),
# (jack_frank_porteous_cork)-[:born]->(twenty_five_june_1989),
# (jonathan_grant_evans)-[:plays_as]->(defender),
# (manuel_obafemi_akanji)-[:refers_to]->(akanji),
# (harry_nicholas_arter)-[:born]->(twenty_eight_december_1989),
# (jonathan_grant_evans)-[:plays_for]->(manchester_united),
# (anass_zaroury)-[:born]->(seven_november_2000),
# (pablo_sarabia_garcia)-[:played_for]->(getafe),
# (jonathan_grant_evans)-[:has_nationality]->(irish),
# (pablo_sarabia_garcia)-[:plays_for]->(wolverhampton_wanderers),
# (luke_chambers)-[:played_for]->(july_2012),
# (manuel_obafemi_akanji)-[:born]->(nineteen_july_1995),
# (wayne_robert_hennessey)-[:played_for]->(wolverhampton_wanderers),
# (darren_edward_andrew_randolph)-[:plays_as]->(goalkeeper),
# (abdoulaye_doucoure)-[:played_for]->(rennes),
# (aaron_james_ramsey)-[:played_for]->(stoke_city),
# (darren_edward_andrew_randolph)-[:has_nationality]->(irish),
# (aaron_william_cresswell)-[:played_for]->(ipswich),
# (michail_gregory_antonio)-[:plays_as]->(forward),
# (adam_david_lallana)-[:born]->(ten_may_1988),
# (ionut_andrei_radu)-[:plays_as]->(romanian),
# (carlos_henrique_casimiro)-[:plays_as]->(brazilian),
# (ben_gannon_doak)-[:played_for]->(ayr_united),
# (george_henry_ivor_baldock)-[:played_for]->(milton_keynes_dons),
# (thomas_kaminski)-[:has_nationality]->(belgian),
# (abdoulaye_doucoure)-[:originates_from]->(france),
# (obinze_angelo_ogbonna)-[:played_for]->(torino),
# (matthew_thomas_ritchie)-[:plays_as]->(right_back),
# (jay_enrique_rodriguez)-[:plays_for]->(burnley),
# (daniel_william_john_ings)-[:refers_to]->(ings),
# (pascal_gross)-[:born]->(fifteen_june_1991),
# (adam_david_lallana)-[:played_for]->(afc_bournemouth),
# (ben_gannon_doak)-[:played_for]->(dalry_rovers),
# (aaron_william_cresswell)-[:refers_to]->(cresswell),
# (kevin_de_bruyne)-[:played_for]->(genk),
# (fraser_gerard_forster)-[:refers_to]->(forster),
# (timothy_michael_ream)-[:played_for]->(st_louis_scott_gallagher),
# (antonee_robinson)-[:played_for]->(evertons),
# (altay_bayindir)-[:played_for]->(fenerbahce),
# (thomas_kaminski)-[:plays_as]->(goalkeeper),
# (lewis_carl_dunk)-[:played_for]->(wimbledon),
# (wayne_robert_hennessey)-[:plays_as]->(goalkeeper),
# (hugo_hadrien_dominique_lloris)-[:refers_to]->(lloris),
# (adam_david_lallana)-[:refers_to]->(lallana),
# (thomas_alun_lockyer)-[:played_for]->(cardiff_city),
# (obinze_angelo_ogbonna)-[:refers_to]->(ogbonna),
# (adam_david_lallana)-[:played_for]->(southampton),
# (christopher_paul_basham)-[:played_for]->(rochdale),
# (lewis_carl_dunk)-[:has_nationality]->(english),
# (jack_frank_porteous_cork)-[:played_for]->(chelsea),
# (pablo_sarabia_garcia)-[:played_for]->(real_madrid),
# (kevin_de_bruyne)-[:has_nationality]->(belgian),
# (jeremy_baffour_doku)-[:played_for]->(anderlecht),
# (adam_david_lallana)-[:plays_for]->(brighton_amp),
# (manuel_obafemi_akanji)-[:plays_as]->(centre_back),
# (manuel_obafemi_akanji)-[:plays_for]->(manchester_city),
# (fraser_gerard_forster)-[:born]->(seventeen_march_1988),
# (carlos_henrique_casimiro)-[:refers_to]->(casemiro),
# (adam_david_lallana)-[:played_for]->(southamptons),
# (aaron_james_ramsey)-[:plays_as]->(box_to_box),
# (hugo_hadrien_dominique_lloris)-[:played_for]->(olympique_lyonnais),
# (matthew_thomas_ritchie)-[:played_for]->(swindon_town),
# (james_philip_milner)-[:has_nationality]->(english),
# (burnley)-[:refers_to]->(chelsea),
# (daniel_william_john_ings)-[:plays_for]->(west_ham_united),
# (christopher_paul_basham)-[:plays_as]->(centre_back),
# (timothy_michael_krul)-[:refers_to]->(krul),
# (michail_gregory_antonio)-[:refers_to]->(antonio),
# (craig_dawson)-[:played_for]->(rochdale),
# (daniel_johnson_burn)-[:plays_for]->(newcastle_united),
# (aaron_james_ramsey)-[:plays_as]->(midfielder),
# (seamus_coleman)-[:born]->(eleven_october_1988),
# (seamus_coleman)-[:played_for]->(sligo_rovers),
# (thomas_david_heaton)-[:plays_as]->(goalkeeper),
# (nathaniel_edwin_clyne)-[:plays_for]->(crystal_palace),
# (antonee_robinson)-[:refers_to]->(robinson),
# (jeremy_baffour_doku)-[:has_nationality]->(belgian),
# (manuel_obafemi_akanji)-[:played_for]->(fc_basel),
# (eric_jeremy_edgar_dier)-[:refers_to]->(dier),
# (christian_dannemann_eriksen)-[:has_nationality]->(danish),
# (mark_maria_hubertus_flekken)-[:born]->(thirteen_june_1993),
# (matthew_thomas_ritchie)-[:plays_as]->(right_winger),
# (thiago_emiliano_da_silva)-[:plays_for]->(chelsea),
# (manuel_obafemi_akanji)-[:has_nationality]->(swiss),
# (pablo_sarabia_garcia)-[:plays_as]->(right_winger),
# (timothy_michael_ream)-[:plays_for]->(fulham),
# (christian_dannemann_eriksen)-[:played_for]->(tottenham_hotspur),
# (nathaniel_edwin_clyne)-[:plays_as]->(right_back),
# (ben_gannon_doak)-[:plays_as]->(winger),
# (timothy_michael_krul)-[:played_for]->(ado_den_haag),
# (craig_dawson)-[:played_for]->(watford),
# (daniel_william_john_ings)-[:born]->(twenty_three_july_1992),
# (mark_maria_hubertus_flekken)-[:plays_as]->(goalkeeper),
# (jay_enrique_rodriguez)-[:played_for]->(burnley),
# (daniel_johnson_burn)-[:played_for]->(wigan_athletic),
# (jeremy_baffour_doku)-[:plays_as]->(winger),
# (jonathan_grant_evans)-[:born]->(three_january_1988),
# (obinze_angelo_ogbonna)-[:has_nationality]->(italian),
# (christian_dannemann_eriksen)-[:plays_as]->(midfielder),
# (pablo_sarabia_garcia)-[:played_for]->(sevilla),
# (ivan_perisic)-[:plays_for]->(tottenham_hotspur),
# (daniel_william_john_ings)-[:played_for]->(burnleys),
# (kouassi_ryan_sessegnon)-[:refers_to]->(sessegnon),
# (craig_dawson)-[:plays_as]->(centre_back),
# (eric_jeremy_edgar_dier)-[:plays_as]->(centre_back),
# (kouassi_ryan_sessegnon)-[:plays_as]->(left_winger),
# (thomas_cairney)-[:played_for]->(hull_city),
# (aaron_james_ramsey)-[:plays_for]->(cardiff_city),
# (dier)-[:plays_as]->(centre_back),
# (thomas_david_heaton)-[:played_for]->(cardiff_city),
# (scott_paul_carson)-[:born]->(three_september_1985),
# (thomas_alun_lockyer)-[:born]->(three_december_1994),
# (ionut_andrei_radu)-[:refers_to]->(ionut_radu),
# (michail_gregory_antonio)-[:played_for]->(southampton),
# (thomas_cairney)-[:refers_to]->(cairney),
# (matthew_thomas_ritchie)-[:born]->(ten_september_1989),
# (kouassi_ryan_sessegnon)-[:born]->(eighteen_may_2000),
# (luke_chambers)-[:born]->(twenty_eight_september_1985),
# (ionut_andrei_radu)-[:plays_for]->(afc_bournemouth),
# (wayne_robert_hennessey)-[:played_for]->(burnley),
# (aaron_william_cresswell)-[:played_for]->(west_ham_united),
# (darren_edward_andrew_randolph)-[:plays_for]->(afc_bournemouth),
# (scott_paul_carson)-[:played_for]->(manchester_united),
# (thiago_emiliano_da_silva)-[:played_for]->(porto),
# (james_philip_milner)-[:plays_for]->(brighton_amp),
# (ionut_andrei_radu)-[:plays_as]->(goalkeeper),
# (pascal_gross)-[:plays_for]->(brighton_amp),
# (thomas_alun_lockyer)-[:plays_for]->(luton_town),
# (thomas_alun_lockyer)-[:plays_as]->(centre_back),
# (abdoulaye_doucoure)-[:refers_to]->(doucoure),
# (eric_jeremy_edgar_dier)-[:originates_from]->(portugal),
# (craig_dawson)-[:born]->(six_may_1990),
# (dier)-[:plays_as]->(right_back),
# (michail_gregory_antonio)-[:played_for]->(sheffield_wednesday),
# (obinze_angelo_ogbonna)-[:born]->(twenty_three_may_1988),
# (michail_gregory_antonio)-[:born]->(twenty_eight_march_1990),
# (jeremy_baffour_doku)-[:played_for]->(kvc_olympic_deurne),
# (obinze_angelo_ogbonna)-[:plays_for]->(west_ham_united),
# (christopher_paul_basham)-[:plays_as]->(defensive_midfielder),
# (nathaniel_edwin_clyne)-[:has_nationality]->(english),
# (ben_gannon_doak)-[:refers_to]->(doak),
# (kevin_de_bruyne)-[:plays_for]->(manchester_city),
# (jonathan_grant_evans)-[:played_for]->(manchester_united),
# (aaron_william_cresswell)-[:has_nationality]->(english),
# (jeremy_baffour_doku)-[:plays_for]->(rennes),
# (timothy_michael_ream)-[:played_for]->(st_dominic),
# (manuel_obafemi_akanji)-[:played_for]->(fc_winterthur),
# (hugo_hadrien_dominique_lloris)-[:played_for]->(ogc_nice);

# %%
len(RE_list)
# Out:
# 50

# %%
RE_list[40:50]
# Out:
# [[('eric_jeremy_edgar_dier', 'born', 'fifteen_january_1994'),
#   ('eric_jeremy_edgar_dier', 'has_nationality', 'english'),
#   ('eric_jeremy_edgar_dier', 'plays_for', 'tottenham_hotspur'),
#   ('eric_jeremy_edgar_dier', 'refers_to', 'dier'),
#   ('eric_jeremy_edgar_dier', 'plays_as', 'defensive_midfielder'),
#   ('eric_jeremy_edgar_dier', 'plays_as', 'centre-back'),
#   ('eric_jeremy_edgar_dier', 'plays_as', 'right-back'),
#   ('eric_jeremy_edgar_dier', 'refers_to', 'dier'),
#   ('eric_jeremy_edgar_dier', 'originates_from', 'portugal'),
#   ('dier', 'plays_as', 'defensive_midfielder'),
#   ('dier', 'plays_as', 'centre-back'),
#   ('dier', 'plays_as', 'right-back')],
#  [('dier', 'plays_as', 'right-back'),
#   ('dier', 'plays_as', 'right-back'),
#   ('dier', 'plays_as', 'right-back'),
#   ('dier', 'plays_as', 'right-back'),
#   ('dier', 'plays_as', 'right-back'),
#   ('dier', 'plays_as', 'right-back'),
#   ('dier', 'plays_as', 'right-back'),
#   ('dier', 'plays_as', 'right-back')],
#  [('ben_gannon_doak', 'born', 'eleven_november_2005'),
#   ('ben_gannon_doak', 'has_nationality', 'scottish'),
#   ('ben_gannon_doak', 'plays_as', 'winger'),
#   ('ben_gannon_doak', 'plays_for', 'liverpool'),
#   ('ben_gannon_doak', 'refers_to', 'doak'),
#   ('ben_gannon_doak', 'played_for', 'dalry_rovers'),
#   ('ben_gannon_doak', 'played_for', 'ayr_united'),
#   ('ben_gannon_doak', 'played_for', 'celtic')],
#  [('antonee_robinson', 'born', 'august_8,_1997'),
#   ('antonee_robinson', 'has_nationality', 'american'),
#   ('antonee_robinson', 'plays_as', 'left-back'),
#   ('antonee_robinson', 'plays_for', 'fulham'),
#   ('antonee_robinson', 'refers_to', 'robinson'),
#   ('antonee_robinson', 'played_for', "everton's"),
#   ('antonee_robinson', 'played_for', 'everton')],
#  [('anass_zaroury', 'born', 'seven_november_2000'),
#   ('anass_zaroury', 'plays_as', 'winger'),
#   ('anass_zaroury', 'plays_for', 'burnley'),
#   ('anass_zaroury', 'originates_from', 'belgium'),
#   ('anass_zaroury', 'refers_to', 'zaroury'),
#   ('anass_zaroury', 'played_for', 'charleroi'),
#   ('anass_zaroury', 'played_for', 'lommel')],
#  [('altay_bayindir', 'born', 'fourteen_april_1998'),
#   ('altay_bayindir', 'has_nationality', 'turkish'),
#   ('altay_bayindir', 'plays_as', 'goalkeeper'),
#   ('altay_bayindir', 'plays_for', 'fenerbahce'),
#   ('altay_bayindir', 'played_for', 'mke_ankaragucu'),
#   ('altay_bayindir', 'refers_to', 'bayindir'),
#   ('altay_bayindir', 'played_for', 'mke_ankaragucu'),
#   ('altay_bayindir', 'played_for', 'caykur_rizespor'),
#   ('altay_bayindir', 'played_for', 'fenerbahce'),
#   ('harun_tekin', 'born', 'nineteen_august_2019')],
#  [('scott_paul_carson', 'born', 'three_september_1985'),
#   ('scott_paul_carson', 'has_nationality', 'english'),
#   ('scott_paul_carson', 'plays_as', 'goalkeeper'),
#   ('scott_paul_carson', 'plays_for', 'manchester_city'),
#   ('scott_paul_carson', 'refers_to', 'carson'),
#   ('scott_paul_carson', 'played_for', 'leeds_united'),
#   ('scott_paul_carson', 'played_for', 'manchester_united'),
#   ('scott_paul_carson', 'played_for', 'liverpool'),
#   ('scott_paul_carson', 'played_for', 'liverpool')],
#  [('abdoulaye_doucoure', 'born', 'one_january_1993'),
#   ('abdoulaye_doucoure', 'plays_as', 'central_midfielder'),
#   ('abdoulaye_doucoure', 'plays_for', 'everton'),
#   ('abdoulaye_doucoure', 'originates_from', 'france'),
#   ('abdoulaye_doucoure', 'refers_to', 'doucoure'),
#   ('abdoulaye_doucoure', 'refers_to', 'doucoure'),
#   ('abdoulaye_doucoure', 'played_for', 'rennes')],
#  [('nathaniel_edwin_clyne', 'born', 'five_april_1991'),
#   ('nathaniel_edwin_clyne', 'has_nationality', 'english'),
#   ('nathaniel_edwin_clyne', 'plays_as', 'right-back'),
#   ('nathaniel_edwin_clyne', 'plays_for', 'crystal_palace'),
#   ('nathaniel_edwin_clyne', 'refers_to', 'clyne'),
#   ('nathaniel_edwin_clyne', 'played_for', 'crystal_palace'),
#   ('nathaniel_edwin_clyne', 'played_for', 'southampton'),
#   ('nathaniel_edwin_clyne', 'played_for', 'liverpool')],
#  [('michail_gregory_antonio', 'born', 'twenty_eight_march_1990'),
#   ('michail_gregory_antonio', 'plays_as', 'forward'),
#   ('michail_gregory_antonio', 'plays_for', 'west_ham_united'),
#   ('michail_gregory_antonio', 'originates_from', 'england'),
#   ('michail_gregory_antonio', 'refers_to', 'antonio'),
#   ('michail_gregory_antonio', 'played_for', 'southampton'),
#   ('michail_gregory_antonio', 'played_for', 'colchester_united'),
#   ('michail_gregory_antonio', 'played_for', 'sheffield_wednesday'),
#   ('michail_gregory_antonio', 'played_for', 'nottingham_forest')]]

# %%
if create_DB:
    with graphDB_Driver.session() as graphDB_Session:
        # Create nodes
        graphDB_Session.run(cqlEmpty)

# %%
RE_output_set
# Out:
# {('aaron_james_ramsey', 'born', 'twenty_six_december_1990'),
#  ('aaron_james_ramsey', 'has_nationality', 'welsh'),
#  ('aaron_james_ramsey', 'played_for', 'arsenal'),
#  ('aaron_james_ramsey', 'played_for', 'cardiff_city'),
#  ('aaron_james_ramsey', 'played_for', 'stoke_city'),
#  ('aaron_james_ramsey', 'plays_as', 'box-to-box'),
#  ('aaron_james_ramsey', 'plays_as', 'midfielder'),
#  ('aaron_james_ramsey', 'plays_for', 'cardiff_city'),
#  ('aaron_william_cresswell', 'born', 'fifteen_december_1989'),
#  ('aaron_william_cresswell', 'has_nationality', 'english'),
#  ('aaron_william_cresswell', 'played_for', 'ipswich'),
#  ('aaron_william_cresswell', 'played_for', 'ipswich_town'),
#  ('aaron_william_cresswell', 'played_for', 'west_ham_united'),
#  ('aaron_william_cresswell', 'plays_as', 'left-back'),
#  ('aaron_william_cresswell', 'plays_for', 'west_ham_united'),
#  ('aaron_william_cresswell', 'refers_to', 'cresswell'),
#  ('abdoulaye_doucoure', 'born', 'one_january_1993'),
#  ('abdoulaye_doucoure', 'originates_from', 'france'),
#  ('abdoulaye_doucoure', 'played_for', 'rennes'),
#  ('abdoulaye_doucoure', 'plays_as', 'central_midfielder'),
#  ('abdoulaye_doucoure', 'plays_for', 'everton'),
#  ('abdoulaye_doucoure', 'refers_to', 'doucoure'),
#  ('adam_david_lallana', 'born', 'ten_may_1988'),
#  ('adam_david_lallana', 'has_nationality', 'english'),
#  ('adam_david_lallana', 'played_for', 'afc_bournemouth'),
#  ('adam_david_lallana', 'played_for', 'bournemouth'),
#  ('adam_david_lallana', 'played_for', 'liverpool'),
#  ('adam_david_lallana', 'played_for', 'southampton'),
#  ('adam_david_lallana', 'played_for', "southampton's"),
#  ('adam_david_lallana', 'plays_as', 'attacking_midfielder'),
#  ('adam_david_lallana', 'plays_for', 'brighton_&amp'),
#  ('adam_david_lallana', 'refers_to', 'lallana'),
#  ('altay_bayindir', 'born', 'fourteen_april_1998'),
#  ('altay_bayindir', 'has_nationality', 'turkish'),
#  ('altay_bayindir', 'played_for', 'caykur_rizespor'),
#  ('altay_bayindir', 'played_for', 'fenerbahce'),
#  ('altay_bayindir', 'played_for', 'mke_ankaragucu'),
#  ('altay_bayindir', 'plays_as', 'goalkeeper'),
#  ('altay_bayindir', 'plays_for', 'fenerbahce'),
#  ('altay_bayindir', 'refers_to', 'bayindir'),
#  ('anass_zaroury', 'born', 'seven_november_2000'),
#  ('anass_zaroury', 'originates_from', 'belgium'),
#  ('anass_zaroury', 'played_for', 'charleroi'),
#  ('anass_zaroury', 'played_for', 'lommel'),
#  ('anass_zaroury', 'plays_as', 'winger'),
#  ('anass_zaroury', 'plays_for', 'burnley'),
#  ('anass_zaroury', 'refers_to', 'zaroury'),
#  ('antonee_robinson', 'born', 'august_8,_1997'),
#  ('antonee_robinson', 'has_nationality', 'american'),
#  ('antonee_robinson', 'played_for', 'everton'),
#  ('antonee_robinson', 'played_for', "everton's"),
#  ('antonee_robinson', 'plays_as', 'left-back'),
#  ('antonee_robinson', 'plays_for', 'fulham'),
#  ('antonee_robinson', 'refers_to', 'robinson'),
#  ('ben_gannon_doak', 'born', 'eleven_november_2005'),
#  ('ben_gannon_doak', 'has_nationality', 'scottish'),
#  ('ben_gannon_doak', 'played_for', 'ayr_united'),
#  ('ben_gannon_doak', 'played_for', 'celtic'),
#  ('ben_gannon_doak', 'played_for', 'dalry_rovers'),
#  ('ben_gannon_doak', 'plays_as', 'winger'),
#  ('ben_gannon_doak', 'plays_for', 'liverpool'),
#  ('ben_gannon_doak', 'refers_to', 'doak'),
#  ('burnley', 'refers_to', 'chelsea'),
#  ('carlos_henrique_casimiro', 'born', 'twenty_three_february_1992'),
#  ('carlos_henrique_casimiro', 'played_for', 'sao_paulo'),
#  ('carlos_henrique_casimiro', 'plays_as', 'brazilian'),
#  ('carlos_henrique_casimiro', 'plays_as', 'defensive_midfielder'),
#  ('carlos_henrique_casimiro', 'plays_as', 'midfielder'),
#  ('carlos_henrique_casimiro', 'plays_for', 'manchester_united'),
#  ('carlos_henrique_casimiro', 'refers_to', 'casemiro'),
#  ('chambers', 'plays_as', 'right_back'),
#  ('christian_dannemann_eriksen', 'born', 'fourteen_february_1992'),
#  ('christian_dannemann_eriksen', 'has_nationality', 'danish'),
#  ('christian_dannemann_eriksen', 'played_for', 'tottenham_hotspur'),
#  ('christian_dannemann_eriksen', 'plays_as', 'midfielder'),
#  ('christian_dannemann_eriksen', 'plays_for', 'manchester_united'),
#  ('christian_dannemann_eriksen', 'refers_to', 'eriksen'),
#  ('christopher_paul_basham', 'born', 'twenty_july_1988'),
#  ('christopher_paul_basham', 'has_nationality', 'english'),
#  ('christopher_paul_basham', 'played_for', 'bolton_wanderers'),
#  ('christopher_paul_basham', 'played_for', 'newcastle_united'),
#  ('christopher_paul_basham', 'played_for', 'rochdale'),
#  ('christopher_paul_basham', 'played_for', 'stafford_rangers'),
#  ('christopher_paul_basham', 'plays_as', 'centre_back'),
#  ('christopher_paul_basham', 'plays_as', 'defensive_midfielder'),
#  ('christopher_paul_basham', 'plays_for', 'sheffield_united'),
#  ('craig_dawson', 'born', 'six_may_1990'),
#  ('craig_dawson', 'has_nationality', 'english'),
#  ('craig_dawson', 'played_for', 'bolton_wanderers'),
#  ('craig_dawson', 'played_for', 'radcliffe_borough'),
#  ('craig_dawson', 'played_for', 'rochdale'),
#  ('craig_dawson', 'played_for', 'watford'),
#  ('craig_dawson', 'played_for', 'west_bromwich_albion'),
#  ('craig_dawson', 'played_for', 'west_ham_united'),
#  ('craig_dawson', 'plays_as', 'centre-back'),
#  ('craig_dawson', 'plays_for', 'wolverhampton_wanderers'),
#  ('daniel_johnson_burn', 'born', 'nine_may_1992'),
#  ('daniel_johnson_burn', 'has_nationality', 'english'),
#  ('daniel_johnson_burn', 'played_for', 'darlington'),
#  ('daniel_johnson_burn', 'played_for', 'fulham'),
#  ('daniel_johnson_burn', 'played_for', 'wigan_athletic'),
#  ('daniel_johnson_burn', 'played_for', 'yeovil_town'),
#  ('daniel_johnson_burn', 'plays_as', 'centre-back'),
#  ('daniel_johnson_burn', 'plays_as', 'left-back'),
#  ('daniel_johnson_burn', 'plays_for', 'newcastle_united'),
#  ('daniel_william_john_ings', 'born', 'twenty_three_july_1992'),
#  ('daniel_william_john_ings', 'has_nationality', 'english'),
#  ('daniel_william_john_ings', 'played_for', 'afc_bournemouth'),
#  ('daniel_william_john_ings', 'played_for', "burnley's"),
#  ('daniel_william_john_ings', 'played_for', 'dorchester_town'),
#  ('daniel_william_john_ings', 'played_for', 'southampton'),
#  ('daniel_william_john_ings', 'plays_as', 'forward'),
#  ('daniel_william_john_ings', 'plays_for', 'west_ham_united'),
#  ('daniel_william_john_ings', 'refers_to', 'ings'),
#  ('darren_edward_andrew_randolph', 'born', 'twelve_may_1987'),
#  ('darren_edward_andrew_randolph', 'has_nationality', 'irish'),
#  ('darren_edward_andrew_randolph', 'played_for', 'charlton_athletic'),
#  ('darren_edward_andrew_randolph', 'plays_as', 'goalkeeper'),
#  ('darren_edward_andrew_randolph', 'plays_for', 'afc_bournemouth'),
#  ('darren_edward_andrew_randolph', 'refers_to', 'randolph'),
#  ('dier', 'plays_as', 'centre-back'),
#  ('dier', 'plays_as', 'defensive_midfielder'),
#  ('dier', 'plays_as', 'right-back'),
#  ('eric_jeremy_edgar_dier', 'born', 'fifteen_january_1994'),
#  ('eric_jeremy_edgar_dier', 'has_nationality', 'english'),
#  ('eric_jeremy_edgar_dier', 'originates_from', 'portugal'),
#  ('eric_jeremy_edgar_dier', 'plays_as', 'centre-back'),
#  ('eric_jeremy_edgar_dier', 'plays_as', 'defensive_midfielder'),
#  ('eric_jeremy_edgar_dier', 'plays_as', 'right-back'),
#  ('eric_jeremy_edgar_dier', 'plays_for', 'tottenham_hotspur'),
#  ('eric_jeremy_edgar_dier', 'refers_to', 'dier'),
#  ('fraser_gerard_forster', 'born', 'seventeen_march_1988'),
#  ('fraser_gerard_forster', 'has_nationality', 'english'),
#  ('fraser_gerard_forster', 'played_for', 'celtic'),
#  ('fraser_gerard_forster', 'played_for', 'newcastle_united'),
#  ('fraser_gerard_forster', 'played_for', 'norwich_city'),
#  ('fraser_gerard_forster', 'played_for', 'rovers'),
#  ('fraser_gerard_forster', 'plays_as', 'goalkeeper'),
#  ('fraser_gerard_forster', 'plays_for', 'tottenham_hotspur'),
#  ('fraser_gerard_forster', 'refers_to', 'forster'),
#  ('george_henry_ivor_baldock', 'born', 'nine_march_1993'),
#  ('george_henry_ivor_baldock', 'originates_from', 'england'),
#  ('george_henry_ivor_baldock', 'played_for', 'milton_keynes_dons'),
#  ('george_henry_ivor_baldock', 'plays_as', 'right_back'),
#  ('george_henry_ivor_baldock', 'plays_for', 'sheffield_united'),
#  ('george_henry_ivor_baldock', 'refers_to', 'baldock'),
#  ('harry_nicholas_arter', 'born', 'twenty_eight_december_1989'),
#  ('harry_nicholas_arter', 'played_for', 'bournemouth'),
#  ('harry_nicholas_arter', 'played_for', 'carlisle_united'),
#  ('harry_nicholas_arter', 'played_for', 'charlton_athletic'),
#  ('harry_nicholas_arter', 'played_for', 'nottingham_forest'),
#  ('harry_nicholas_arter', 'played_for', 'welling_united'),
#  ('harry_nicholas_arter', 'plays_as', 'defensive_midfielder'),
#  ('harun_tekin', 'born', 'nineteen_august_2019'),
#  ('hugo_hadrien_dominique_lloris', 'born', 'twenty_six_december_1986'),
#  ('hugo_hadrien_dominique_lloris', 'has_nationality', 'french'),
#  ('hugo_hadrien_dominique_lloris', 'played_for', 'milan'),
#  ('hugo_hadrien_dominique_lloris', 'played_for', 'ogc_nice'),
#  ('hugo_hadrien_dominique_lloris', 'played_for', 'olympique_lyonnais'),
#  ('hugo_hadrien_dominique_lloris', 'plays_as', 'goalkeeper'),
#  ('hugo_hadrien_dominique_lloris', 'plays_for', 'tottenham_hotspur'),
#  ('hugo_hadrien_dominique_lloris', 'refers_to', 'lloris'),
#  ('ionut_andrei_radu', 'born', 'twenty_eight_may_1997'),
#  ('ionut_andrei_radu', 'played_for', 'avellino'),
#  ('ionut_andrei_radu', 'played_for', 'inter_milan'),
#  ('ionut_andrei_radu', 'plays_as', 'goalkeeper'),
#  ('ionut_andrei_radu', 'plays_as', 'romanian'),
#  ('ionut_andrei_radu', 'plays_for', 'afc_bournemouth'),
#  ('ionut_andrei_radu', 'refers_to', 'andrei_radu'),
#  ('ionut_andrei_radu', 'refers_to', 'ionut_radu'),
#  ('ionut_andrei_radu', 'refers_to', 'radu'),
#  ('ivan_perisic', 'born', 'two_february_1989'),
#  ('ivan_perisic', 'has_nationality', 'croatian'),
#  ('ivan_perisic', 'played_for', 'hajduk_split'),
#  ('ivan_perisic', 'played_for', 'sochaux'),
#  ('ivan_perisic', 'plays_as', 'attacking_midfielder'),
#  ('ivan_perisic', 'plays_as', 'left_wing-back'),
#  ('ivan_perisic', 'plays_as', 'left_winger'),
#  ('ivan_perisic', 'plays_for', 'tottenham_hotspur'),
#  ('jack_frank_porteous_cork', 'born', 'twenty_five_june_1989'),
#  ('jack_frank_porteous_cork', 'has_nationality', 'english'),
#  ('jack_frank_porteous_cork', 'played_for', 'burnley'),
#  ('jack_frank_porteous_cork', 'played_for', 'chelsea'),
#  ('jack_frank_porteous_cork', 'played_for', 'scunthorpe_united'),
#  ('jack_frank_porteous_cork', 'played_for', 'southampton'),
#  ('jack_frank_porteous_cork', 'played_for', 'swansea_city'),
#  ('jack_frank_porteous_cork', 'plays_as', 'midfielder'),
#  ('jack_frank_porteous_cork', 'plays_for', 'burnley'),
#  ('james_philip_milner', 'born', 'four_january_1986'),
#  ('james_philip_milner', 'has_nationality', 'english'),
#  ('james_philip_milner', 'played_for', 'leeds_united'),
#  ('james_philip_milner', 'played_for', 'leeds_youth'),
#  ('james_philip_milner', 'played_for', 'swindon_town'),
#  ('james_philip_milner', 'plays_as', 'midfielder'),
#  ('james_philip_milner', 'plays_for', 'brighton_&amp'),
#  ('james_philip_milner', 'refers_to', 'milner'),
#  ('james_philip_milner', 'refers_to', "milner's"),
#  ('jay_enrique_rodriguez', 'born', 'twenty_nine_july_1989'),
#  ('jay_enrique_rodriguez', 'has_nationality', 'english'),
#  ('jay_enrique_rodriguez', 'played_for', 'burnley'),
#  ('jay_enrique_rodriguez', 'plays_as', 'striker'),
#  ('jay_enrique_rodriguez', 'plays_for', 'burnley'),
#  ('jay_enrique_rodriguez', 'refers_to', 'rodriguez'),
#  ('jeremy_baffour_doku', 'born', 'twenty_seven_may_2002'),
#  ('jeremy_baffour_doku', 'has_nationality', 'belgian'),
#  ('jeremy_baffour_doku', 'played_for', 'anderlecht'),
#  ('jeremy_baffour_doku', 'played_for', 'beerschot'),
#  ('jeremy_baffour_doku', 'played_for', 'kvc_olympic_deurne'),
#  ('jeremy_baffour_doku', 'plays_as', 'winger'),
#  ('jeremy_baffour_doku', 'plays_for', 'rennes'),
#  ('jonathan_grant_evans', 'born', 'three_january_1988'),
#  ('jonathan_grant_evans', 'has_nationality', 'irish'),
#  ('jonathan_grant_evans', 'played_for', 'manchester_united'),
#  ('jonathan_grant_evans', 'played_for', 'sunderland'),
#  ('jonathan_grant_evans', 'plays_as', 'defender'),
#  ('jonathan_grant_evans', 'plays_for', 'manchester_united'),
#  ('jonathan_grant_evans', 'refers_to', 'evans'),
#  ('kevin_de_bruyne', 'born', 'twenty_eight_june_1991'),
#  ('kevin_de_bruyne', 'has_nationality', 'belgian'),
#  ('kevin_de_bruyne', 'played_for', 'genk'),
#  ('kevin_de_bruyne', 'played_for', 'werder_bremen'),
#  ('kevin_de_bruyne', 'played_for', 'wolfsburg'),
#  ('kevin_de_bruyne', 'plays_as', 'midfielder'),
#  ('kevin_de_bruyne', 'plays_for', 'manchester_city'),
#  ('kevin_de_bruyne', 'refers_to', 'de_bruyne'),
#  ('kevin_de_bruyne', 'refers_to', 'pundits'),
#  ('kouassi_ryan_sessegnon', 'born', 'eighteen_may_2000'),
#  ('kouassi_ryan_sessegnon', 'has_nationality', 'english'),
#  ('kouassi_ryan_sessegnon', 'played_for', 'fulham'),
#  ('kouassi_ryan_sessegnon', 'plays_as', 'left-back'),
#  ('kouassi_ryan_sessegnon', 'plays_as', 'left_midfielder'),
#  ('kouassi_ryan_sessegnon', 'plays_as', 'left_winger'),
#  ('kouassi_ryan_sessegnon', 'plays_for', 'tottenham_hotspur'),
#  ('kouassi_ryan_sessegnon', 'refers_to', 'sessegnon'),
#  ('lewis_carl_dunk', 'born', 'twenty_one_november_1991'),
#  ('lewis_carl_dunk', 'has_nationality', 'english'),
#  ('lewis_carl_dunk', 'played_for', 'albion"'),
#  ('lewis_carl_dunk', 'played_for', 'brighton'),
#  ('lewis_carl_dunk', 'played_for', "brighton's"),
#  ('lewis_carl_dunk', 'played_for', 'bristol_city'),
#  ('lewis_carl_dunk', 'played_for', 'wimbledon'),
#  ('lewis_carl_dunk', 'plays_as', 'centre-back'),
#  ('lewis_carl_dunk', 'plays_for', 'brighton_&amp'),
#  ('luke_chambers', 'born', 'twenty_eight_september_1985'),
#  ('luke_chambers', 'played_for', 'ipswich_town'),
#  ('luke_chambers', 'played_for', 'july_2012'),
#  ('luke_chambers', 'played_for', 'northampton_town'),
#  ('luke_chambers', 'played_for', 'nottingham_forest'),
#  ('luke_chambers', 'plays_as', 'centre_back'),
#  ('luke_chambers', 'plays_as', 'defender'),
#  ('luke_chambers', 'plays_as', 'right_back'),
#  ('luke_chambers', 'refers_to', 'chambers'),
#  ('manuel_obafemi_akanji', 'born', 'nineteen_july_1995'),
#  ('manuel_obafemi_akanji', 'has_nationality', 'swiss'),
#  ('manuel_obafemi_akanji', 'played_for', 'fc_basel'),
#  ('manuel_obafemi_akanji', 'played_for', 'fc_winterthur'),
#  ('manuel_obafemi_akanji', 'played_for', 'fifteen_april_2015'),
#  ('manuel_obafemi_akanji', 'plays_as', 'centre-back'),
#  ('manuel_obafemi_akanji', 'plays_as', 'full-back'),
#  ('manuel_obafemi_akanji', 'plays_for', 'manchester_city'),
#  ('manuel_obafemi_akanji', 'refers_to', 'akanji'),
#  ('mark_maria_hubertus_flekken', 'born', 'thirteen_june_1993'),
#  ('mark_maria_hubertus_flekken', 'has_nationality', 'dutch'),
#  ('mark_maria_hubertus_flekken', 'played_for', 'limburg'),
#  ('mark_maria_hubertus_flekken', 'plays_as', 'goalkeeper'),
#  ('mark_maria_hubertus_flekken', 'plays_for', 'brentford'),
#  ('mark_maria_hubertus_flekken', 'refers_to', 'flekken'),
#  ('matthew_thomas_ritchie', 'born', 'ten_september_1989'),
#  ('matthew_thomas_ritchie', 'played_for', 'bournemouth'),
#  ('matthew_thomas_ritchie', 'played_for', 'newcastle_united'),
#  ('matthew_thomas_ritchie', 'played_for', 'portsmouth'),
#  ('matthew_thomas_ritchie', 'played_for', 'swindon_town'),
#  ('matthew_thomas_ritchie', 'plays_as', 'right-back'),
#  ('matthew_thomas_ritchie', 'plays_as', 'right_winger'),
#  ('matthew_thomas_ritchie', 'plays_for', 'newcastle_united'),
#  ('matthew_thomas_ritchie', 'refers_to', 'ritchie'),
#  ('michail_gregory_antonio', 'born', 'twenty_eight_march_1990'),
#  ('michail_gregory_antonio', 'originates_from', 'england'),
#  ('michail_gregory_antonio', 'played_for', 'colchester_united'),
#  ('michail_gregory_antonio', 'played_for', 'nottingham_forest'),
#  ('michail_gregory_antonio', 'played_for', 'sheffield_wednesday'),
#  ('michail_gregory_antonio', 'played_for', 'southampton'),
#  ('michail_gregory_antonio', 'plays_as', 'forward'),
#  ('michail_gregory_antonio', 'plays_for', 'west_ham_united'),
#  ('michail_gregory_antonio', 'refers_to', 'antonio'),
#  ('nathaniel_edwin_clyne', 'born', 'five_april_1991'),
#  ('nathaniel_edwin_clyne', 'has_nationality', 'english'),
#  ('nathaniel_edwin_clyne', 'played_for', 'crystal_palace'),
#  ('nathaniel_edwin_clyne', 'played_for', 'liverpool'),
#  ('nathaniel_edwin_clyne', 'played_for', 'southampton'),
#  ('nathaniel_edwin_clyne', 'plays_as', 'right-back'),
#  ('nathaniel_edwin_clyne', 'plays_for', 'crystal_palace'),
#  ('nathaniel_edwin_clyne', 'refers_to', 'clyne'),
#  ('obinze_angelo_ogbonna', 'born', 'twenty_three_may_1988'),
#  ('obinze_angelo_ogbonna', 'has_nationality', 'italian'),
#  ('obinze_angelo_ogbonna', 'played_for', 'july_2013'),
#  ('obinze_angelo_ogbonna', 'played_for', 'nuova_cassino'),
#  ('obinze_angelo_ogbonna', 'played_for', 'torino'),
#  ('obinze_angelo_ogbonna', 'plays_as', 'centre-back'),
#  ('obinze_angelo_ogbonna', 'plays_for', 'west_ham_united'),
#  ('obinze_angelo_ogbonna', 'refers_to', 'ogbonna'),
#  ('pablo_sarabia_garcia', 'born', 'eleven_may_1992'),
#  ('pablo_sarabia_garcia', 'has_nationality', 'spanish'),
#  ('pablo_sarabia_garcia', 'played_for', 'getafe'),
#  ('pablo_sarabia_garcia', 'played_for', 'real_madrid'),
#  ('pablo_sarabia_garcia', 'played_for', 'sevilla'),
#  ('pablo_sarabia_garcia', 'plays_as', 'attacking_midfielder'),
#  ('pablo_sarabia_garcia', 'plays_as', 'right_winger'),
#  ('pablo_sarabia_garcia', 'plays_for', 'wolverhampton_wanderers'),
#  ('pascal_gross', 'born', 'fifteen_june_1991'),
#  ('pascal_gross', 'has_nationality', 'german'),
#  ('pascal_gross', 'played_for', 'gross'),
#  ('pascal_gross', 'plays_as', 'defensive_midfielder'),
#  ('pascal_gross', 'plays_as', 'forward'),
#  ('pascal_gross', 'plays_as', 'right-back'),
#  ('pascal_gross', 'plays_for', 'brighton_&amp'),
#  ('scott_paul_carson', 'born', 'three_september_1985'),
#  ('scott_paul_carson', 'has_nationality', 'english'),
#  ('scott_paul_carson', 'played_for', 'leeds_united'),
#  ('scott_paul_carson', 'played_for', 'liverpool'),
#  ('scott_paul_carson', 'played_for', 'manchester_united'),
#  ('scott_paul_carson', 'plays_as', 'goalkeeper'),
#  ('scott_paul_carson', 'plays_for', 'manchester_city'),
#  ('scott_paul_carson', 'refers_to', 'carson'),
#  ('seamus_coleman', 'born', 'eleven_october_1988'),
#  ('seamus_coleman', 'has_nationality', 'irish'),
#  ('seamus_coleman', 'played_for', 'sligo_rovers'),
#  ('seamus_coleman', 'played_for', "st_catherine's"),
#  ('seamus_coleman', 'plays_as', 'right-back'),
#  ('seamus_coleman', 'plays_for', 'everton'),
#  ('seamus_coleman', 'refers_to', 'coleman'),
#  ('sint-truiden', 'born', 'twenty_five_november_2018'),
#  ('thiago_emiliano_da_silva', 'born', 'twenty_two_september_1984'),
#  ('thiago_emiliano_da_silva', 'has_nationality', 'brazilian'),
#  ('thiago_emiliano_da_silva', 'played_for', 'dynamo_moscow'),
#  ('thiago_emiliano_da_silva', 'played_for', 'porto'),
#  ('thiago_emiliano_da_silva', 'played_for', 'rs_futebol'),
#  ('thiago_emiliano_da_silva', 'plays_as', 'centre-back'),
#  ('thiago_emiliano_da_silva', 'plays_as', 'midfielder'),
#  ('thiago_emiliano_da_silva', 'plays_for', 'chelsea'),
#  ('thiago_emiliano_da_silva', 'refers_to', 'silva'),
#  ('thomas_alun_lockyer', 'born', 'three_december_1994'),
#  ('thomas_alun_lockyer', 'has_nationality', 'welsh'),
#  ('thomas_alun_lockyer', 'played_for', 'cardiff_city'),
#  ('thomas_alun_lockyer', 'played_for', 'radyr_rangers'),
#  ('thomas_alun_lockyer', 'played_for', 'rovers'),
#  ('thomas_alun_lockyer', 'plays_as', 'centre-back'),
#  ('thomas_alun_lockyer', 'plays_for', 'luton_town'),
#  ('thomas_alun_lockyer', 'refers_to', 'lockyer'),
#  ('thomas_cairney', 'born', 'twenty_january_1991'),
#  ('thomas_cairney', 'played_for', 'blackburn_rovers'),
#  ('thomas_cairney', 'played_for', 'hull_city'),
#  ('thomas_cairney', 'plays_as', 'attacking_midfielder'),
#  ('thomas_cairney', 'plays_as', 'central_midfielder'),
#  ('thomas_cairney', 'plays_for', 'fulham'),
#  ('thomas_cairney', 'refers_to', 'cairney'),
#  ('thomas_david_heaton', 'born', 'fifteen_april_1986'),
#  ('thomas_david_heaton', 'has_nationality', 'english'),
#  ('thomas_david_heaton', 'played_for', 'cardiff_city'),
#  ('thomas_david_heaton', 'played_for', 'manchester_united'),
#  ('thomas_david_heaton', 'played_for', 'queens_park_rangers'),
#  ('thomas_david_heaton', 'played_for', 'royal_antwerp'),
#  ('thomas_david_heaton', 'played_for', 'swindon_town'),
#  ('thomas_david_heaton', 'plays_as', 'goalkeeper'),
#  ('thomas_david_heaton', 'plays_for', 'manchester_united'),
#  ('thomas_david_heaton', 'refers_to', 'heaton'),
#  ('thomas_kaminski', 'born', 'twenty_three_october_1992'),
#  ('thomas_kaminski', 'has_nationality', 'belgian'),
#  ('thomas_kaminski', 'played_for', 'germinal_beerschot'),
#  ('thomas_kaminski', 'played_for', 'oh_leuven'),
#  ('thomas_kaminski', 'plays_as', 'goalkeeper'),
#  ('thomas_kaminski', 'plays_for', 'luton_town'),
#  ('thomas_kaminski', 'refers_to', 'kaminski'),
#  ('timothy_michael_krul', 'born', 'three_april_1988'),
#  ('timothy_michael_krul', 'has_nationality', 'dutch'),
#  ('timothy_michael_krul', 'played_for', 'ado_den_haag'),
#  ('timothy_michael_krul', 'played_for', 'newcastle_united'),
#  ('timothy_michael_krul', 'plays_as', 'goalkeeper'),
#  ('timothy_michael_krul', 'plays_for', 'luton_town'),
#  ('timothy_michael_krul', 'refers_to', 'krul'),
#  ('timothy_michael_ream', 'born', 'october_5,_1987'),
#  ('timothy_michael_ream', 'has_nationality', 'american'),
#  ('timothy_michael_ream', 'played_for', 'st._dominic'),
#  ('timothy_michael_ream', 'played_for', 'st._louis_scott_gallagher'),
#  ('timothy_michael_ream', 'plays_as', 'center-back'),
#  ('timothy_michael_ream', 'plays_as', 'left-back'),
#  ('timothy_michael_ream', 'plays_for', 'fulham'),
#  ('timothy_michael_ream', 'refers_to', 'ream'),
#  ('tottenham_hotspur', 'played_for', 'inter_milan'),
#  ('wayne_robert_hennessey', 'born', 'twenty_four_january_1987'),
#  ('wayne_robert_hennessey', 'has_nationality', 'welsh'),
#  ('wayne_robert_hennessey', 'played_for', 'burnley'),
#  ('wayne_robert_hennessey', 'played_for', 'crystal_palace'),
#  ('wayne_robert_hennessey', 'played_for', 'palace'),
#  ('wayne_robert_hennessey', 'played_for', 'wolverhampton_wanderers'),
#  ('wayne_robert_hennessey', 'plays_as', 'goalkeeper'),
#  ('wayne_robert_hennessey', 'plays_for', 'nottingham_forest'),
#  ('wayne_robert_hennessey', 'refers_to', "hennessey's")}

# %%
query_set_RE = create_relation_query(RE_output_set)
# Show results
query_set_RE
# Out:
# {'(aaron_james_ramsey)-[:born]->(twenty_six_december_1990)',
#  '(aaron_james_ramsey)-[:has_nationality]->(welsh)',
#  '(aaron_james_ramsey)-[:played_for]->(arsenal)',
#  '(aaron_james_ramsey)-[:played_for]->(cardiff_city)',
#  '(aaron_james_ramsey)-[:played_for]->(stoke_city)',
#  '(aaron_james_ramsey)-[:plays_as]->(box_to_box)',
#  '(aaron_james_ramsey)-[:plays_as]->(midfielder)',
#  '(aaron_james_ramsey)-[:plays_for]->(cardiff_city)',
#  '(aaron_william_cresswell)-[:born]->(fifteen_december_1989)',
#  '(aaron_william_cresswell)-[:has_nationality]->(english)',
#  '(aaron_william_cresswell)-[:played_for]->(ipswich)',
#  '(aaron_william_cresswell)-[:played_for]->(ipswich_town)',
#  '(aaron_william_cresswell)-[:played_for]->(west_ham_united)',
#  '(aaron_william_cresswell)-[:plays_as]->(left_back)',
#  '(aaron_william_cresswell)-[:plays_for]->(west_ham_united)',
#  '(aaron_william_cresswell)-[:refers_to]->(cresswell)',
#  '(abdoulaye_doucoure)-[:born]->(one_january_1993)',
#  '(abdoulaye_doucoure)-[:originates_from]->(france)',
#  '(abdoulaye_doucoure)-[:played_for]->(rennes)',
#  '(abdoulaye_doucoure)-[:plays_as]->(central_midfielder)',
#  '(abdoulaye_doucoure)-[:plays_for]->(everton)',
#  '(abdoulaye_doucoure)-[:refers_to]->(doucoure)',
#  '(adam_david_lallana)-[:born]->(ten_may_1988)',
#  '(adam_david_lallana)-[:has_nationality]->(english)',
#  '(adam_david_lallana)-[:played_for]->(afc_bournemouth)',
#  '(adam_david_lallana)-[:played_for]->(bournemouth)',
#  '(adam_david_lallana)-[:played_for]->(liverpool)',
#  '(adam_david_lallana)-[:played_for]->(southampton)',
#  '(adam_david_lallana)-[:played_for]->(southamptons)',
#  '(adam_david_lallana)-[:plays_as]->(attacking_midfielder)',
#  '(adam_david_lallana)-[:plays_for]->(brighton_amp)',
#  '(adam_david_lallana)-[:refers_to]->(lallana)',
#  '(altay_bayindir)-[:born]->(fourteen_april_1998)',
#  '(altay_bayindir)-[:has_nationality]->(turkish)',
#  '(altay_bayindir)-[:played_for]->(caykur_rizespor)',
#  '(altay_bayindir)-[:played_for]->(fenerbahce)',
#  '(altay_bayindir)-[:played_for]->(mke_ankaragucu)',
#  '(altay_bayindir)-[:plays_as]->(goalkeeper)',
#  '(altay_bayindir)-[:plays_for]->(fenerbahce)',
#  '(altay_bayindir)-[:refers_to]->(bayindir)',
#  '(anass_zaroury)-[:born]->(seven_november_2000)',
#  '(anass_zaroury)-[:originates_from]->(belgium)',
#  '(anass_zaroury)-[:played_for]->(charleroi)',
#  '(anass_zaroury)-[:played_for]->(lommel)',
#  '(anass_zaroury)-[:plays_as]->(winger)',
#  '(anass_zaroury)-[:plays_for]->(burnley)',
#  '(anass_zaroury)-[:refers_to]->(zaroury)',
#  '(antonee_robinson)-[:born]->(august_8_1997)',
#  '(antonee_robinson)-[:has_nationality]->(american)',
#  '(antonee_robinson)-[:played_for]->(everton)',
#  '(antonee_robinson)-[:played_for]->(evertons)',
#  '(antonee_robinson)-[:plays_as]->(left_back)',
#  '(antonee_robinson)-[:plays_for]->(fulham)',
#  '(antonee_robinson)-[:refers_to]->(robinson)',
#  '(ben_gannon_doak)-[:born]->(eleven_november_2005)',
#  '(ben_gannon_doak)-[:has_nationality]->(scottish)',
#  '(ben_gannon_doak)-[:played_for]->(ayr_united)',
#  '(ben_gannon_doak)-[:played_for]->(celtic)',
#  '(ben_gannon_doak)-[:played_for]->(dalry_rovers)',
#  '(ben_gannon_doak)-[:plays_as]->(winger)',
#  '(ben_gannon_doak)-[:plays_for]->(liverpool)',
#  '(ben_gannon_doak)-[:refers_to]->(doak)',
#  '(burnley)-[:refers_to]->(chelsea)',
#  '(carlos_henrique_casimiro)-[:born]->(twenty_three_february_1992)',
#  '(carlos_henrique_casimiro)-[:played_for]->(sao_paulo)',
#  '(carlos_henrique_casimiro)-[:plays_as]->(brazilian)',
#  '(carlos_henrique_casimiro)-[:plays_as]->(defensive_midfielder)',
#  '(carlos_henrique_casimiro)-[:plays_as]->(midfielder)',
#  '(carlos_henrique_casimiro)-[:plays_for]->(manchester_united)',
#  '(carlos_henrique_casimiro)-[:refers_to]->(casemiro)',
#  '(chambers)-[:plays_as]->(right_back)',
#  '(christian_dannemann_eriksen)-[:born]->(fourteen_february_1992)',
#  '(christian_dannemann_eriksen)-[:has_nationality]->(danish)',
#  '(christian_dannemann_eriksen)-[:played_for]->(tottenham_hotspur)',
#  '(christian_dannemann_eriksen)-[:plays_as]->(midfielder)',
#  '(christian_dannemann_eriksen)-[:plays_for]->(manchester_united)',
#  '(christian_dannemann_eriksen)-[:refers_to]->(eriksen)',
#  '(christopher_paul_basham)-[:born]->(twenty_july_1988)',
#  '(christopher_paul_basham)-[:has_nationality]->(english)',
#  '(christopher_paul_basham)-[:played_for]->(bolton_wanderers)',
#  '(christopher_paul_basham)-[:played_for]->(newcastle_united)',
#  '(christopher_paul_basham)-[:played_for]->(rochdale)',
#  '(christopher_paul_basham)-[:played_for]->(stafford_rangers)',
#  '(christopher_paul_basham)-[:plays_as]->(centre_back)',
#  '(christopher_paul_basham)-[:plays_as]->(defensive_midfielder)',
#  '(christopher_paul_basham)-[:plays_for]->(sheffield_united)',
#  '(craig_dawson)-[:born]->(six_may_1990)',
#  '(craig_dawson)-[:has_nationality]->(english)',
#  '(craig_dawson)-[:played_for]->(bolton_wanderers)',
#  '(craig_dawson)-[:played_for]->(radcliffe_borough)',
#  '(craig_dawson)-[:played_for]->(rochdale)',
#  '(craig_dawson)-[:played_for]->(watford)',
#  '(craig_dawson)-[:played_for]->(west_bromwich_albion)',
#  '(craig_dawson)-[:played_for]->(west_ham_united)',
#  '(craig_dawson)-[:plays_as]->(centre_back)',
#  '(craig_dawson)-[:plays_for]->(wolverhampton_wanderers)',
#  '(daniel_johnson_burn)-[:born]->(nine_may_1992)',
#  '(daniel_johnson_burn)-[:has_nationality]->(english)',
#  '(daniel_johnson_burn)-[:played_for]->(darlington)',
#  '(daniel_johnson_burn)-[:played_for]->(fulham)',
#  '(daniel_johnson_burn)-[:played_for]->(wigan_athletic)',
#  '(daniel_johnson_burn)-[:played_for]->(yeovil_town)',
#  '(daniel_johnson_burn)-[:plays_as]->(centre_back)',
#  '(daniel_johnson_burn)-[:plays_as]->(left_back)',
#  '(daniel_johnson_burn)-[:plays_for]->(newcastle_united)',
#  '(daniel_william_john_ings)-[:born]->(twenty_three_july_1992)',
#  '(daniel_william_john_ings)-[:has_nationality]->(english)',
#  '(daniel_william_john_ings)-[:played_for]->(afc_bournemouth)',
#  '(daniel_william_john_ings)-[:played_for]->(burnleys)',
#  '(daniel_william_john_ings)-[:played_for]->(dorchester_town)',
#  '(daniel_william_john_ings)-[:played_for]->(southampton)',
#  '(daniel_william_john_ings)-[:plays_as]->(forward)',
#  '(daniel_william_john_ings)-[:plays_for]->(west_ham_united)',
#  '(daniel_william_john_ings)-[:refers_to]->(ings)',
#  '(darren_edward_andrew_randolph)-[:born]->(twelve_may_1987)',
#  '(darren_edward_andrew_randolph)-[:has_nationality]->(irish)',
#  '(darren_edward_andrew_randolph)-[:played_for]->(charlton_athletic)',
#  '(darren_edward_andrew_randolph)-[:plays_as]->(goalkeeper)',
#  '(darren_edward_andrew_randolph)-[:plays_for]->(afc_bournemouth)',
#  '(darren_edward_andrew_randolph)-[:refers_to]->(randolph)',
#  '(dier)-[:plays_as]->(centre_back)',
#  '(dier)-[:plays_as]->(defensive_midfielder)',
#  '(dier)-[:plays_as]->(right_back)',
#  '(eric_jeremy_edgar_dier)-[:born]->(fifteen_january_1994)',
#  '(eric_jeremy_edgar_dier)-[:has_nationality]->(english)',
#  '(eric_jeremy_edgar_dier)-[:originates_from]->(portugal)',
#  '(eric_jeremy_edgar_dier)-[:plays_as]->(centre_back)',
#  '(eric_jeremy_edgar_dier)-[:plays_as]->(defensive_midfielder)',
#  '(eric_jeremy_edgar_dier)-[:plays_as]->(right_back)',
#  '(eric_jeremy_edgar_dier)-[:plays_for]->(tottenham_hotspur)',
#  '(eric_jeremy_edgar_dier)-[:refers_to]->(dier)',
#  '(fraser_gerard_forster)-[:born]->(seventeen_march_1988)',
#  '(fraser_gerard_forster)-[:has_nationality]->(english)',
#  '(fraser_gerard_forster)-[:played_for]->(celtic)',
#  '(fraser_gerard_forster)-[:played_for]->(newcastle_united)',
#  '(fraser_gerard_forster)-[:played_for]->(norwich_city)',
#  '(fraser_gerard_forster)-[:played_for]->(rovers)',
#  '(fraser_gerard_forster)-[:plays_as]->(goalkeeper)',
#  '(fraser_gerard_forster)-[:plays_for]->(tottenham_hotspur)',
#  '(fraser_gerard_forster)-[:refers_to]->(forster)',
#  '(george_henry_ivor_baldock)-[:born]->(nine_march_1993)',
#  '(george_henry_ivor_baldock)-[:originates_from]->(england)',
#  '(george_henry_ivor_baldock)-[:played_for]->(milton_keynes_dons)',
#  '(george_henry_ivor_baldock)-[:plays_as]->(right_back)',
#  '(george_henry_ivor_baldock)-[:plays_for]->(sheffield_united)',
#  '(george_henry_ivor_baldock)-[:refers_to]->(baldock)',
#  '(harry_nicholas_arter)-[:born]->(twenty_eight_december_1989)',
#  '(harry_nicholas_arter)-[:played_for]->(bournemouth)',
#  '(harry_nicholas_arter)-[:played_for]->(carlisle_united)',
#  '(harry_nicholas_arter)-[:played_for]->(charlton_athletic)',
#  '(harry_nicholas_arter)-[:played_for]->(nottingham_forest)',
#  '(harry_nicholas_arter)-[:played_for]->(welling_united)',
#  '(harry_nicholas_arter)-[:plays_as]->(defensive_midfielder)',
#  '(harun_tekin)-[:born]->(nineteen_august_2019)',
#  '(hugo_hadrien_dominique_lloris)-[:born]->(twenty_six_december_1986)',
#  '(hugo_hadrien_dominique_lloris)-[:has_nationality]->(french)',
#  '(hugo_hadrien_dominique_lloris)-[:played_for]->(milan)',
#  '(hugo_hadrien_dominique_lloris)-[:played_for]->(ogc_nice)',
#  '(hugo_hadrien_dominique_lloris)-[:played_for]->(olympique_lyonnais)',
#  '(hugo_hadrien_dominique_lloris)-[:plays_as]->(goalkeeper)',
#  '(hugo_hadrien_dominique_lloris)-[:plays_for]->(tottenham_hotspur)',
#  '(hugo_hadrien_dominique_lloris)-[:refers_to]->(lloris)',
#  '(ionut_andrei_radu)-[:born]->(twenty_eight_may_1997)',
#  '(ionut_andrei_radu)-[:played_for]->(avellino)',
#  '(ionut_andrei_radu)-[:played_for]->(inter_milan)',
#  '(ionut_andrei_radu)-[:plays_as]->(goalkeeper)',
#  '(ionut_andrei_radu)-[:plays_as]->(romanian)',
#  '(ionut_andrei_radu)-[:plays_for]->(afc_bournemouth)',
#  '(ionut_andrei_radu)-[:refers_to]->(andrei_radu)',
#  '(ionut_andrei_radu)-[:refers_to]->(ionut_radu)',
#  '(ionut_andrei_radu)-[:refers_to]->(radu)',
#  '(ivan_perisic)-[:born]->(two_february_1989)',
#  '(ivan_perisic)-[:has_nationality]->(croatian)',
#  '(ivan_perisic)-[:played_for]->(hajduk_split)',
#  '(ivan_perisic)-[:played_for]->(sochaux)',
#  '(ivan_perisic)-[:plays_as]->(attacking_midfielder)',
#  '(ivan_perisic)-[:plays_as]->(left_wing_back)',
#  '(ivan_perisic)-[:plays_as]->(left_winger)',
#  '(ivan_perisic)-[:plays_for]->(tottenham_hotspur)',
#  '(jack_frank_porteous_cork)-[:born]->(twenty_five_june_1989)',
#  '(jack_frank_porteous_cork)-[:has_nationality]->(english)',
#  '(jack_frank_porteous_cork)-[:played_for]->(burnley)',
#  '(jack_frank_porteous_cork)-[:played_for]->(chelsea)',
#  '(jack_frank_porteous_cork)-[:played_for]->(scunthorpe_united)',
#  '(jack_frank_porteous_cork)-[:played_for]->(southampton)',
#  '(jack_frank_porteous_cork)-[:played_for]->(swansea_city)',
#  '(jack_frank_porteous_cork)-[:plays_as]->(midfielder)',
#  '(jack_frank_porteous_cork)-[:plays_for]->(burnley)',
#  '(james_philip_milner)-[:born]->(four_january_1986)',
#  '(james_philip_milner)-[:has_nationality]->(english)',
#  '(james_philip_milner)-[:played_for]->(leeds_united)',
#  '(james_philip_milner)-[:played_for]->(leeds_youth)',
#  '(james_philip_milner)-[:played_for]->(swindon_town)',
#  '(james_philip_milner)-[:plays_as]->(midfielder)',
#  '(james_philip_milner)-[:plays_for]->(brighton_amp)',
#  '(james_philip_milner)-[:refers_to]->(milner)',
#  '(james_philip_milner)-[:refers_to]->(milners)',
#  '(jay_enrique_rodriguez)-[:born]->(twenty_nine_july_1989)',
#  '(jay_enrique_rodriguez)-[:has_nationality]->(english)',
#  '(jay_enrique_rodriguez)-[:played_for]->(burnley)',
#  '(jay_enrique_rodriguez)-[:plays_as]->(striker)',
#  '(jay_enrique_rodriguez)-[:plays_for]->(burnley)',
#  '(jay_enrique_rodriguez)-[:refers_to]->(rodriguez)',
#  '(jeremy_baffour_doku)-[:born]->(twenty_seven_may_2002)',
#  '(jeremy_baffour_doku)-[:has_nationality]->(belgian)',
#  '(jeremy_baffour_doku)-[:played_for]->(anderlecht)',
#  '(jeremy_baffour_doku)-[:played_for]->(beerschot)',
#  '(jeremy_baffour_doku)-[:played_for]->(kvc_olympic_deurne)',
#  '(jeremy_baffour_doku)-[:plays_as]->(winger)',
#  '(jeremy_baffour_doku)-[:plays_for]->(rennes)',
#  '(jonathan_grant_evans)-[:born]->(three_january_1988)',
#  '(jonathan_grant_evans)-[:has_nationality]->(irish)',
#  '(jonathan_grant_evans)-[:played_for]->(manchester_united)',
#  '(jonathan_grant_evans)-[:played_for]->(sunderland)',
#  '(jonathan_grant_evans)-[:plays_as]->(defender)',
#  '(jonathan_grant_evans)-[:plays_for]->(manchester_united)',
#  '(jonathan_grant_evans)-[:refers_to]->(evans)',
#  '(kevin_de_bruyne)-[:born]->(twenty_eight_june_1991)',
#  '(kevin_de_bruyne)-[:has_nationality]->(belgian)',
#  '(kevin_de_bruyne)-[:played_for]->(genk)',
#  '(kevin_de_bruyne)-[:played_for]->(werder_bremen)',
#  '(kevin_de_bruyne)-[:played_for]->(wolfsburg)',
#  '(kevin_de_bruyne)-[:plays_as]->(midfielder)',
#  '(kevin_de_bruyne)-[:plays_for]->(manchester_city)',
#  '(kevin_de_bruyne)-[:refers_to]->(de_bruyne)',
#  '(kevin_de_bruyne)-[:refers_to]->(pundits)',
#  '(kouassi_ryan_sessegnon)-[:born]->(eighteen_may_2000)',
#  '(kouassi_ryan_sessegnon)-[:has_nationality]->(english)',
#  '(kouassi_ryan_sessegnon)-[:played_for]->(fulham)',
#  '(kouassi_ryan_sessegnon)-[:plays_as]->(left_back)',
#  '(kouassi_ryan_sessegnon)-[:plays_as]->(left_midfielder)',
#  '(kouassi_ryan_sessegnon)-[:plays_as]->(left_winger)',
#  '(kouassi_ryan_sessegnon)-[:plays_for]->(tottenham_hotspur)',
#  '(kouassi_ryan_sessegnon)-[:refers_to]->(sessegnon)',
#  '(lewis_carl_dunk)-[:born]->(twenty_one_november_1991)',
#  '(lewis_carl_dunk)-[:has_nationality]->(english)',
#  '(lewis_carl_dunk)-[:played_for]->(albion)',
#  '(lewis_carl_dunk)-[:played_for]->(brighton)',
#  '(lewis_carl_dunk)-[:played_for]->(brightons)',
#  '(lewis_carl_dunk)-[:played_for]->(bristol_city)',
#  '(lewis_carl_dunk)-[:played_for]->(wimbledon)',
#  '(lewis_carl_dunk)-[:plays_as]->(centre_back)',
#  '(lewis_carl_dunk)-[:plays_for]->(brighton_amp)',
#  '(luke_chambers)-[:born]->(twenty_eight_september_1985)',
#  '(luke_chambers)-[:played_for]->(ipswich_town)',
#  '(luke_chambers)-[:played_for]->(july_2012)',
#  '(luke_chambers)-[:played_for]->(northampton_town)',
#  '(luke_chambers)-[:played_for]->(nottingham_forest)',
#  '(luke_chambers)-[:plays_as]->(centre_back)',
#  '(luke_chambers)-[:plays_as]->(defender)',
#  '(luke_chambers)-[:plays_as]->(right_back)',
#  '(luke_chambers)-[:refers_to]->(chambers)',
#  '(manuel_obafemi_akanji)-[:born]->(nineteen_july_1995)',
#  '(manuel_obafemi_akanji)-[:has_nationality]->(swiss)',
#  '(manuel_obafemi_akanji)-[:played_for]->(fc_basel)',
#  '(manuel_obafemi_akanji)-[:played_for]->(fc_winterthur)',
#  '(manuel_obafemi_akanji)-[:played_for]->(fifteen_april_2015)',
#  '(manuel_obafemi_akanji)-[:plays_as]->(centre_back)',
#  '(manuel_obafemi_akanji)-[:plays_as]->(full_back)',
#  '(manuel_obafemi_akanji)-[:plays_for]->(manchester_city)',
#  '(manuel_obafemi_akanji)-[:refers_to]->(akanji)',
#  '(mark_maria_hubertus_flekken)-[:born]->(thirteen_june_1993)',
#  '(mark_maria_hubertus_flekken)-[:has_nationality]->(dutch)',
#  '(mark_maria_hubertus_flekken)-[:played_for]->(limburg)',
#  '(mark_maria_hubertus_flekken)-[:plays_as]->(goalkeeper)',
#  '(mark_maria_hubertus_flekken)-[:plays_for]->(brentford)',
#  '(mark_maria_hubertus_flekken)-[:refers_to]->(flekken)',
#  '(matthew_thomas_ritchie)-[:born]->(ten_september_1989)',
#  '(matthew_thomas_ritchie)-[:played_for]->(bournemouth)',
#  '(matthew_thomas_ritchie)-[:played_for]->(newcastle_united)',
#  '(matthew_thomas_ritchie)-[:played_for]->(portsmouth)',
#  '(matthew_thomas_ritchie)-[:played_for]->(swindon_town)',
#  '(matthew_thomas_ritchie)-[:plays_as]->(right_back)',
#  '(matthew_thomas_ritchie)-[:plays_as]->(right_winger)',
#  '(matthew_thomas_ritchie)-[:plays_for]->(newcastle_united)',
#  '(matthew_thomas_ritchie)-[:refers_to]->(ritchie)',
#  '(michail_gregory_antonio)-[:born]->(twenty_eight_march_1990)',
#  '(michail_gregory_antonio)-[:originates_from]->(england)',
#  '(michail_gregory_antonio)-[:played_for]->(colchester_united)',
#  '(michail_gregory_antonio)-[:played_for]->(nottingham_forest)',
#  '(michail_gregory_antonio)-[:played_for]->(sheffield_wednesday)',
#  '(michail_gregory_antonio)-[:played_for]->(southampton)',
#  '(michail_gregory_antonio)-[:plays_as]->(forward)',
#  '(michail_gregory_antonio)-[:plays_for]->(west_ham_united)',
#  '(michail_gregory_antonio)-[:refers_to]->(antonio)',
#  '(nathaniel_edwin_clyne)-[:born]->(five_april_1991)',
#  '(nathaniel_edwin_clyne)-[:has_nationality]->(english)',
#  '(nathaniel_edwin_clyne)-[:played_for]->(crystal_palace)',
#  '(nathaniel_edwin_clyne)-[:played_for]->(liverpool)',
#  '(nathaniel_edwin_clyne)-[:played_for]->(southampton)',
#  '(nathaniel_edwin_clyne)-[:plays_as]->(right_back)',
#  '(nathaniel_edwin_clyne)-[:plays_for]->(crystal_palace)',
#  '(nathaniel_edwin_clyne)-[:refers_to]->(clyne)',
#  '(obinze_angelo_ogbonna)-[:born]->(twenty_three_may_1988)',
#  '(obinze_angelo_ogbonna)-[:has_nationality]->(italian)',
#  '(obinze_angelo_ogbonna)-[:played_for]->(july_2013)',
#  '(obinze_angelo_ogbonna)-[:played_for]->(nuova_cassino)',
#  '(obinze_angelo_ogbonna)-[:played_for]->(torino)',
#  '(obinze_angelo_ogbonna)-[:plays_as]->(centre_back)',
#  '(obinze_angelo_ogbonna)-[:plays_for]->(west_ham_united)',
#  '(obinze_angelo_ogbonna)-[:refers_to]->(ogbonna)',
#  '(pablo_sarabia_garcia)-[:born]->(eleven_may_1992)',
#  '(pablo_sarabia_garcia)-[:has_nationality]->(spanish)',
#  '(pablo_sarabia_garcia)-[:played_for]->(getafe)',
#  '(pablo_sarabia_garcia)-[:played_for]->(real_madrid)',
#  '(pablo_sarabia_garcia)-[:played_for]->(sevilla)',
#  '(pablo_sarabia_garcia)-[:plays_as]->(attacking_midfielder)',
#  '(pablo_sarabia_garcia)-[:plays_as]->(right_winger)',
#  '(pablo_sarabia_garcia)-[:plays_for]->(wolverhampton_wanderers)',
#  '(pascal_gross)-[:born]->(fifteen_june_1991)',
#  '(pascal_gross)-[:has_nationality]->(german)',
#  '(pascal_gross)-[:played_for]->(gross)',
#  '(pascal_gross)-[:plays_as]->(defensive_midfielder)',
#  '(pascal_gross)-[:plays_as]->(forward)',
#  '(pascal_gross)-[:plays_as]->(right_back)',
#  '(pascal_gross)-[:plays_for]->(brighton_amp)',
#  '(scott_paul_carson)-[:born]->(three_september_1985)',
#  '(scott_paul_carson)-[:has_nationality]->(english)',
#  '(scott_paul_carson)-[:played_for]->(leeds_united)',
#  '(scott_paul_carson)-[:played_for]->(liverpool)',
#  '(scott_paul_carson)-[:played_for]->(manchester_united)',
#  '(scott_paul_carson)-[:plays_as]->(goalkeeper)',
#  '(scott_paul_carson)-[:plays_for]->(manchester_city)',
#  '(scott_paul_carson)-[:refers_to]->(carson)',
#  '(seamus_coleman)-[:born]->(eleven_october_1988)',
#  '(seamus_coleman)-[:has_nationality]->(irish)',
#  '(seamus_coleman)-[:played_for]->(sligo_rovers)',
#  '(seamus_coleman)-[:played_for]->(st_catherines)',
#  '(seamus_coleman)-[:plays_as]->(right_back)',
#  '(seamus_coleman)-[:plays_for]->(everton)',
#  '(seamus_coleman)-[:refers_to]->(coleman)',
#  '(sint_truiden)-[:born]->(twenty_five_november_2018)',
#  '(thiago_emiliano_da_silva)-[:born]->(twenty_two_september_1984)',
#  '(thiago_emiliano_da_silva)-[:has_nationality]->(brazilian)',
#  '(thiago_emiliano_da_silva)-[:played_for]->(dynamo_moscow)',
#  '(thiago_emiliano_da_silva)-[:played_for]->(porto)',
#  '(thiago_emiliano_da_silva)-[:played_for]->(rs_futebol)',
#  '(thiago_emiliano_da_silva)-[:plays_as]->(centre_back)',
#  '(thiago_emiliano_da_silva)-[:plays_as]->(midfielder)',
#  '(thiago_emiliano_da_silva)-[:plays_for]->(chelsea)',
#  '(thiago_emiliano_da_silva)-[:refers_to]->(silva)',
#  '(thomas_alun_lockyer)-[:born]->(three_december_1994)',
#  '(thomas_alun_lockyer)-[:has_nationality]->(welsh)',
#  '(thomas_alun_lockyer)-[:played_for]->(cardiff_city)',
#  '(thomas_alun_lockyer)-[:played_for]->(radyr_rangers)',
#  '(thomas_alun_lockyer)-[:played_for]->(rovers)',
#  '(thomas_alun_lockyer)-[:plays_as]->(centre_back)',
#  '(thomas_alun_lockyer)-[:plays_for]->(luton_town)',
#  '(thomas_alun_lockyer)-[:refers_to]->(lockyer)',
#  '(thomas_cairney)-[:born]->(twenty_january_1991)',
#  '(thomas_cairney)-[:played_for]->(blackburn_rovers)',
#  '(thomas_cairney)-[:played_for]->(hull_city)',
#  '(thomas_cairney)-[:plays_as]->(attacking_midfielder)',
#  '(thomas_cairney)-[:plays_as]->(central_midfielder)',
#  '(thomas_cairney)-[:plays_for]->(fulham)',
#  '(thomas_cairney)-[:refers_to]->(cairney)',
#  '(thomas_david_heaton)-[:born]->(fifteen_april_1986)',
#  '(thomas_david_heaton)-[:has_nationality]->(english)',
#  '(thomas_david_heaton)-[:played_for]->(cardiff_city)',
#  '(thomas_david_heaton)-[:played_for]->(manchester_united)',
#  '(thomas_david_heaton)-[:played_for]->(queens_park_rangers)',
#  '(thomas_david_heaton)-[:played_for]->(royal_antwerp)',
#  '(thomas_david_heaton)-[:played_for]->(swindon_town)',
#  '(thomas_david_heaton)-[:plays_as]->(goalkeeper)',
#  '(thomas_david_heaton)-[:plays_for]->(manchester_united)',
#  '(thomas_david_heaton)-[:refers_to]->(heaton)',
#  '(thomas_kaminski)-[:born]->(twenty_three_october_1992)',
#  '(thomas_kaminski)-[:has_nationality]->(belgian)',
#  '(thomas_kaminski)-[:played_for]->(germinal_beerschot)',
#  '(thomas_kaminski)-[:played_for]->(oh_leuven)',
#  '(thomas_kaminski)-[:plays_as]->(goalkeeper)',
#  '(thomas_kaminski)-[:plays_for]->(luton_town)',
#  '(thomas_kaminski)-[:refers_to]->(kaminski)',
#  '(timothy_michael_krul)-[:born]->(three_april_1988)',
#  '(timothy_michael_krul)-[:has_nationality]->(dutch)',
#  '(timothy_michael_krul)-[:played_for]->(ado_den_haag)',
#  '(timothy_michael_krul)-[:played_for]->(newcastle_united)',
#  '(timothy_michael_krul)-[:plays_as]->(goalkeeper)',
#  '(timothy_michael_krul)-[:plays_for]->(luton_town)',
#  '(timothy_michael_krul)-[:refers_to]->(krul)',
#  '(timothy_michael_ream)-[:born]->(october_5_1987)',
#  '(timothy_michael_ream)-[:has_nationality]->(american)',
#  '(timothy_michael_ream)-[:played_for]->(st_dominic)',
#  '(timothy_michael_ream)-[:played_for]->(st_louis_scott_gallagher)',
#  '(timothy_michael_ream)-[:plays_as]->(center_back)',
#  '(timothy_michael_ream)-[:plays_as]->(left_back)',
#  '(timothy_michael_ream)-[:plays_for]->(fulham)',
#  '(timothy_michael_ream)-[:refers_to]->(ream)',
#  '(tottenham_hotspur)-[:played_for]->(inter_milan)',
#  '(wayne_robert_hennessey)-[:born]->(twenty_four_january_1987)',
#  '(wayne_robert_hennessey)-[:has_nationality]->(welsh)',
#  '(wayne_robert_hennessey)-[:played_for]->(burnley)',
#  '(wayne_robert_hennessey)-[:played_for]->(crystal_palace)',
#  '(wayne_robert_hennessey)-[:played_for]->(palace)',
#  '(wayne_robert_hennessey)-[:played_for]->(wolverhampton_wanderers)',
#  '(wayne_robert_hennessey)-[:plays_as]->(goalkeeper)',
#  '(wayne_robert_hennessey)-[:plays_for]->(nottingham_forest)',
#  '(wayne_robert_hennessey)-[:refers_to]->(hennesseys)'}

# %% [markdown]
# ## Create the Final Query

# %%
# cqlCreate = combine_queries(query_set_NER, query_set_RE)
# # Show results
# cqlCreate

# %% [markdown]
# ## Create the Knowledge Graph in Neo4j using Cypher

# %%
# # Database Credentials

# uri = "bolt://localhost:7687" # Click the copy button in the "Bolt port" row from the table that appears when you click NBA_example in Neo4j Desktop
# userName = "neo4j"
# password = "bilalbroski1" # password for Text_Mining_Neo4j DBMS

# %%
# # Connect to the neo4j database server
# graphDB_Driver = GraphDatabase.driver(uri, auth=(userName, password))

# %%
# # variable that should be set to "True" when the CREATE query has to be run
# # The reason why this variable exists, is that if you run the code multiple times 
# # with create_DB set to True, there will be a lot of duplicates within Neo4j
# create_DB = True

# %%
# # Create a few queries to test the Knowledge Graph with after it has been created

# # CQL (=Cypher Query Language) to query all players that played for the Dutch national team
# cqlNationalTeamQuery = """MATCH (player:PLAYER) -[:played_for] -> (country:COUNTRY) 
# WHERE country.name = "Netherlands"
# RETURN player.name
# """
# # CQL (=Cypher Query Language) to query all players that play as goalkeeper
# cqlGoalkeeperQuery = """MATCH (player:PLAYER) -[:plays_as] -> (position:POSITION) 
# WHERE position.name = "Goalkeeper"
# RETURN player.name
# """

# %%
# cqlCreate

# %%
# # Execute the CQL query to create the KG
# if create_DB:
#     with graphDB_Driver.session() as graphDB_Session:
#         # Create nodes
#         graphDB_Session.run(cqlCreate)

# # Show the query that we ran again
# cqlCreate

# %%
# # Execute all other CQL queries and print the results
# with graphDB_Driver.session() as graphDB_Session:
#     # Query the graph #1
#     dutch_players = graphDB_Session.run(cqlNationalTeamQuery)

#     print("Names of all football players that have played for the Dutch national team:")
#     for player in dutch_players:
#         print(player)

#     # Query the graph #2
#     goalkeepers = graphDB_Session.run(cqlGoalkeeperQuery)

#     print('\n')
#     print("Names of players that play as goalkeepers:")
#     for player in goalkeepers:
#         print(player)

# %% [markdown]
# # Appendix with helpful explanations / code:

# %% [markdown]
# ### List of helpful Cypher commands:
# - To show the complete KG:
#     - MATCH (n) RETURN n
# - To delete the complete KG:
#     - MATCH (n) DETACH DELETE n
#
# For an example of what a Python query to create a KG in Cypher/Neo4j should look like: https://github.com/harblaith7/Neo4j-Crash-Course/blob/main/01-initial-data.cypher

# %% [markdown]
# ### Find index:
#
# If you want to know which index a certain text has within the dataset,you can enter the name that starts the text as a string to the begin_str variable.
#
#
# The following code will then print the index of the text that begins like this when you run it:

# %%
# # Define the number of players/texts
# nr_texts = 1031 # set to max number of texts (1031) since you want to search all of these

# # begin_str = "Thomas Alun Lockyer"
# begin_str = "Mark Maria Hubertus Flekken"

# for i in range(nr_texts):
#     with open(f'./data/footballer_{i}.txt', 'r') as f:
#         contents = f.read()
#         # texts.append(contents)
#         if (contents[:len(begin_str)] == begin_str):
#             print(f"The index of the text that starts with '{begin_str}' is: ", i)
#     f.close()
